# %%
text = 'এবারও থার্টি ফার্স্টে খোলা জায়গায় অনুষ্ঠান করা যাবে না'

# %% [markdown]
# ### **BNAUG**

# %%
# !pip install bnaug
# Out:
# Collecting bnaug
#   Downloading bnaug-1.1.2-py3-none-any.whl (4.8 kB)
# Collecting bnlp-toolkit==3.3.2 (from bnaug)
#   Downloading bnlp_toolkit-3.3.2-py3-none-any.whl (23 kB)
# Collecting transformers==4.24.0 (from bnaug)
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 48.4 MB/s eta 0:00:00
# Collecting sentencepiece (from bnlp-toolkit==3.3.2->bnaug)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 61.4 MB/s eta 0:00:00
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (from bnlp-toolkit==3.3.2->bnaug) (4.3.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from bnlp-toolkit==3.3.2->bnaug) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bnlp-toolkit==3.3.2->bnaug) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from bnlp-toolkit==3.3.2->bnaug) (1.11.4)
# Collecting sklearn-crfsuite (from bnlp-toolkit==3.3.2->bnaug)
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from bnlp-toolkit==3.3.2->bnaug) (4.66.1)
# Collecting ftfy (from bnlp-toolkit==3.3.2->bnaug)
#   Downloading ftfy-6.1.3-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 5.0 MB/s eta 0:00:00
# Collecting emoji==1.7.0 (from bnlp-toolkit==3.3.2->bnaug)
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 17.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.24.0->bnaug) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.24.0->bnaug) (0.19.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.24.0->bnaug) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.24.0->bnaug) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.24.0->bnaug) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.24.0->bnaug) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.24.0->bnaug)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 65.6 MB/s eta 0:00:00
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers==4.24.0->bnaug) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers==4.24.0->bnaug) (4.5.0)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy->bnlp-toolkit==3.3.2->bnaug) (0.2.12)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim->bnlp-toolkit==3.3.2->bnaug) (6.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->bnlp-toolkit==3.3.2->bnaug) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->bnlp-toolkit==3.3.2->bnaug) (1.3.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.24.0->bnaug) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.24.0->bnaug) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.24.0->bnaug) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.24.0->bnaug) (2023.11.17)
# Collecting python-crfsuite>=0.8.3 (from sklearn-crfsuite->bnlp-toolkit==3.3.2->bnaug)
#   Downloading python_crfsuite-0.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.5/993.5 kB 38.4 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from sklearn-crfsuite->bnlp-toolkit==3.3.2->bnaug) (1.16.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from sklearn-crfsuite->bnlp-toolkit==3.3.2->bnaug) (0.9.0)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171033 sha256=009ecb021206f2e56fa785fbdc2b35b7ca72b7b3c2b4e1c49a0e94a2afc1b43c
#   Stored in directory: /root/.cache/pip/wheels/31/8a/8c/315c9e5d7773f74b33d5ed33f075b49c6eaeb7cedbb86e2cf8
# Successfully built emoji
# Installing collected packages: tokenizers, sentencepiece, python-crfsuite, emoji, sklearn-crfsuite, ftfy, transformers, bnlp-toolkit, bnaug
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.0
#     Uninstalling tokenizers-0.15.0:
#       Successfully uninstalled tokenizers-0.15.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.2
#     Uninstalling transformers-4.35.2:
#       Successfully uninstalled transformers-4.35.2
# Successfully installed bnaug-1.1.2 bnlp-toolkit-3.3.2 emoji-1.7.0 ftfy-6.1.3 python-crfsuite-0.9.9 sentencepiece-0.1.99 sklearn-crfsuite-0.3.6 tokenizers-0.13.3 transformers-4.24.0

# %%
# !wget https://huggingface.co/sagorsarker/bangla_word2vec/resolve/main/bangla_word2vec_gen4.zip
# !wget https://huggingface.co/sagorsarker/bangla-glove-vectors/resolve/main/bn_glove.300d.zip

# !unzip bangla_word2vec_gen4.zip
# !unzip bn_glove.300d.zip

# !rm -rf bangla_word2vec_gen4.zip
# !rm -rf bn_glove.300d.zip
# Out:
# --2023-12-06 04:55:02--  https://huggingface.co/sagorsarker/bangla_word2vec/resolve/main/bangla_word2vec_gen4.zip
# Resolving huggingface.co (huggingface.co)... 65.8.178.12, 65.8.178.27, 65.8.178.118, ...
# Connecting to huggingface.co (huggingface.co)|65.8.178.12|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/f5/12/f51294acf565f8e7f2b231a61a327e6a79fce680615e3bbbc4850f166e928650/b157fe019ddda848f0195240f636ff2dcb63cbe823c84eed77c129e196105fd1?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27bangla_word2vec_gen4.zip%3B+filename%3D%22bangla_word2vec_gen4.zip%22%3B&response-content-type=application%2Fzip&Expires=1702097702&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=gI3ZNWBdkF%7EEp4cG3v8qEXjogi-m9rfWlnRsYZ1JXo6jz642X3T8cdKjoEJdEqbrcoYRsWT-E9GBndDazRs5pA8H-pWZHs2S1bnnUUiFedQkLrBvpEQLw2k11x4X8pf7x2wWIJTMBWtiiOCB4pNqnMf4vfzp4OwN7TBCxEgiA7jVRRUizAx7L3F9TCDZjfWdWM3Bnj-eKGV0hw3LUwByrAElpCBHtT3vjlpPlgiwXE%7EPYrwB0yZj8TUgcuvQTqNEBoA6Vv3Pozp6kKinwE6cB4uZ5AlIAAkG2fRbygUjbAi-BqE5B7fhnVbPyGQ404VPMq%7EHhrBiR6pI78KKE7WEQQ__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2023-12-06 04:55:02--  https://cdn-lfs.huggingface.co/repos/f5/12/f51294acf565f8e7f2b231a61a327e6a79fce680615e3bbbc4850f166e928650/b157fe019ddda848f0195240f636ff2dcb63cbe823c84eed77c129e196105fd1?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27bangla_word2vec_gen4.zip%3B+filename%3D%22bangla_word2vec_gen4.zip%22%3B&response-content-type=application%2Fzip&Expires=1702097702&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=gI3ZNWBdkF%7EEp4cG3v8qEXjogi-m9rfWlnRsYZ1JXo6jz642X3T8cdKjoEJdEqbrcoYRsWT-E9GBndDazRs5pA8H-pWZHs2S1bnnUUiFedQkLrBvpEQLw2k11x4X8pf7x2wWIJTMBWtiiOCB4pNqnMf4vfzp4OwN7TBCxEgiA7jVRRUizAx7L3F9TCDZjfWdWM3Bnj-eKGV0hw3LUwByrAElpCBHtT3vjlpPlgiwXE%7EPYrwB0yZj8TUgcuvQTqNEBoA6Vv3Pozp6kKinwE6cB4uZ5AlIAAkG2fRbygUjbAi-BqE5B7fhnVbPyGQ404VPMq%7EHhrBiR6pI78KKE7WEQQ__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.239.225.76, 18.239.225.121, 18.239.225.69, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.239.225.76|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 199591017 (190M) [application/zip]
# Saving to: ‘bangla_word2vec_gen4.zip’
#
# bangla_word2vec_gen 100%[===================>] 190.34M  52.5MB/s    in 3.6s
#
# 2023-12-06 04:55:06 (52.5 MB/s) - ‘bangla_word2vec_gen4.zip’ saved [199591017/199591017]
#
# --2023-12-06 04:55:06--  https://huggingface.co/sagorsarker/bangla-glove-vectors/resolve/main/bn_glove.300d.zip
# Resolving huggingface.co (huggingface.co)... 65.8.178.12, 65.8.178.27, 65.8.178.118, ...
# Connecting to huggingface.co (huggingface.co)|65.8.178.12|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/aa/54/aa548a31e1afcb96a938d527a7a3914d612289d4eec18ddd467509e7f2f37969/5d66200bc461365e98afa1ff172c40ebef5fd64e8c8188744a9fe3673148ce11?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27bn_glove.300d.zip%3B+filename%3D%22bn_glove.300d.zip%22%3B&response-content-type=application%2Fzip&Expires=1702097707&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=pnhgVoCnXIXWlDFi98jizkyjdMoBjmuZlQDUyQGpGQpvi0mRSryYS68WR8bJlD7KPtBM6SWfMJrllwRxhY-BH%7EMlLgPSKqiLNGcWkANsHw79Shi8KC%7E3M64pdJ56IcTUMVPcDJoxbutsDmtYKnPd3eLLTg7i%7EeUnEmIfO3FunX92fOclPf1I7s4giosyGxqAPEW040Iv2lEa8WVRzTOuSn5aIUT-zWeUtPWBvXYVrejvoEpbA7XVbcP8TQ0n3EeT%7ENw5zAwymmTMAemvMSXXHxN3hRLcxBq3uEnJOsIGrPMnuNhm5CcXDzV0Mqq82Ud1qQyY9xsBZsI5Z0WBFWrfqA__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2023-12-06 04:55:07--  https://cdn-lfs.huggingface.co/repos/aa/54/aa548a31e1afcb96a938d527a7a3914d612289d4eec18ddd467509e7f2f37969/5d66200bc461365e98afa1ff172c40ebef5fd64e8c8188744a9fe3673148ce11?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27bn_glove.300d.zip%3B+filename%3D%22bn_glove.300d.zip%22%3B&response-content-type=application%2Fzip&Expires=1702097707&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=pnhgVoCnXIXWlDFi98jizkyjdMoBjmuZlQDUyQGpGQpvi0mRSryYS68WR8bJlD7KPtBM6SWfMJrllwRxhY-BH%7EMlLgPSKqiLNGcWkANsHw79Shi8KC%7E3M64pdJ56IcTUMVPcDJoxbutsDmtYKnPd3eLLTg7i%7EeUnEmIfO3FunX92fOclPf1I7s4giosyGxqAPEW040Iv2lEa8WVRzTOuSn5aIUT-zWeUtPWBvXYVrejvoEpbA7XVbcP8TQ0n3EeT%7ENw5zAwymmTMAemvMSXXHxN3hRLcxBq3uEnJOsIGrPMnuNhm5CcXDzV0Mqq82Ud1qQyY9xsBZsI5Z0WBFWrfqA__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.239.225.76, 18.239.225.121, 18.239.225.69, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.239.225.76|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 145929792 (139M) [application/zip]
# Saving to: ‘bn_glove.300d.zip’
#
# bn_glove.300d.zip   100%[===================>] 139.17M  44.5MB/s    in 3.1s
#
# 2023-12-06 04:55:10 (44.5 MB/s) - ‘bn_glove.300d.zip’ saved [145929792/145929792]
#
# Archive:  bangla_word2vec_gen4.zip
#    creating: bangla_word2vec/
#   inflating: bangla_word2vec/README.md
#   inflating: bangla_word2vec/bnwiki_word2vec.model
#   inflating: bangla_word2vec/bnwiki_word2vec.model.syn1neg.npy
#   inflating: bangla_word2vec/bnwiki_word2vec.model.wv.vectors.npy
#   inflating: bangla_word2vec/bnwiki_word2vec.vector
#    creating: bangla_word2vec/evaluations/
#   inflating: bangla_word2vec/evaluations/evaluation.json
# Archive:  bn_glove.300d.zip
#   inflating: bn_glove.300d.txt

# %%
from bnaug.sentence import TokenReplacement

tokr = TokenReplacement()
text = "আমি ঢাকায় বাস করি।"
output = tokr.masking_based(text, sen_n=5)
print(output)
# Out:
# punkt not found. downloading...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# WARNING:root:The current version (3.3.2) of bnlp will not be compatible with the upcoming release.
# If you are using version <=3.3.2 please specify bnlp_toolkit with exact version, otherwise it will raises error in the upcoming version.
# To migrate feel free to checkout the newer version (4.0.0). It will release soon as beta.
# config.json:   0%|          | 0.00/491 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1075         try:
# -> 1076             return importlib.import_module("." + module_name, self.__name__)
#    1077         except Exception as e:
#
# /usr/lib/python3.10/importlib/__init__.py in import_module(name, package)
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.10/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bert/modeling_tf_bert.py in <module>
#      37 )
# ---> 38 from ...modeling_tf_utils import (
#      39     TFCausalLanguageModelingLoss,
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_tf_utils.py in <module>
#      38 from huggingface_hub import Repository, list_repo_files
# ---> 39 from keras.saving.hdf5_format import save_attributes_to_hdf5_group
#      40 from transformers.utils.hub import convert_file_size_to_int, get_checkpoint_shard_files
#
# ModuleNotFoundError: No module named 'keras.saving.hdf5_format'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-16551acbca80> in <cell line: 5>()
#       3 tokr = TokenReplacement()
#       4 text = "আমি ঢাকায় বাস করি।"
# ----> 5 output = tokr.masking_based(text, sen_n=5)
#       6 print(output)
#
# /usr/local/lib/python3.10/dist-packages/bnaug/sentence.py in masking_based(self, sentence, mask_model, sen_n, top_k, device)
#      25         else:
#      26             model_path = mask_model
# ---> 27         unmasker = pipeline('fill-mask', model=model_path, top_k=top_k, device=device)
#      28
#      29         tokens = basic_tokenizer.tokenize(sentence)
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, framework, revision, use_fast, use_auth_token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     725     # Will load the correct model if possible
#     726     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 727     framework, model = infer_framework_load_model(
#     728         model,
#     729         model_classes=model_classes,
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     231                         classes.append(_class)
#     232                 if look_tf:
# --> 233                     _class = getattr(transformers_module, f"TF{architecture}", None)
#     234                     if _class is not None:
#     235                         classes.append(_class)
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#    1065         elif name in self._class_to_module.keys():
#    1066             module = self._get_module(self._class_to_module[name])
# -> 1067             value = getattr(module, name)
#    1068         else:
#    1069             raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#    1064             value = self._get_module(name)
#    1065         elif name in self._class_to_module.keys():
# -> 1066             module = self._get_module(self._class_to_module[name])
#    1067             value = getattr(module, name)
#    1068         else:
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1076             return importlib.import_module("." + module_name, self.__name__)
#    1077         except Exception as e:
# -> 1078             raise RuntimeError(
#    1079                 f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1080                 f" traceback):\n{e}"
#
# RuntimeError: Failed to import transformers.models.bert.modeling_tf_bert because of the following error (look up to see its traceback):
# No module named 'keras.saving.hdf5_format'

# %%
from bnaug.sentence import TokenReplacement

tokr = TokenReplacement()
text = "এবারও থার্টি ফার্স্টে খোলা জায়গায় অনুষ্ঠান করা যাবে না"
model = "bangla_word2vec/bnwiki_word2vec.model"
output = tokr.word2vec_based(text, model=model, sen_n=5, word_n=6)
for i in output:
  print(i)
# Out:
# "Key 'জায়গায়' not present in vocabulary"
# "Key 'ফার্স্টে' not present in vocabulary"
# "Key 'জায়গায়' not present in vocabulary"
# এবারও থার্টি ফার্স্টে খোলা জায়গায় অনুষ্ঠান করা যাবে নি
# এবারও থার্টি ফার্স্টে খোলা জায়গায় অনুষ্ঠান করা যাবে না৷
# এবারও থার্টি ফার্স্টে খোলা জায়গায় অনুষ্ঠান করা যাবে নাই
# এবারও থার্টি ফার্স্টে খোলা জায়গায় অনুষ্ঠান করা যাবে যদি
# এবারও থার্টি ফার্স্টে খোলা জায়গায় অনুষ্ঠান করা যাবে না-
# এবারও থার্টি ফার্স্টে খোলা জায়গায় অনুষ্ঠান করা যাবে সেটা
# এবারও থার্টি ফার্স্টে খোলা জায়গায় অনুষ্ঠান করা যায় না
# এবারও থার্টি ফার্স্টে খোলা জায়গায় অনুষ্ঠান করা যেত না
# এবারও থার্টি ফার্স্টে খোলা জায়গায় অনুষ্ঠান করা যেতো না
# এবারও থার্টি ফার্স্টে খোলা জায়গায় অনুষ্ঠান করা যাচ্ছে না
# এবারও থার্টি ফার্স্টে খোলা জায়গায় অনুষ্ঠান করা যায়- না
# এবারও থার্টি ফার্স্টে খোলা জায়গায় অনুষ্ঠান করা যাচ্ছিল না

# %%
from bnaug.sentence import TokenReplacement

tokr = TokenReplacement()
text = "এমপি নিজাম হাজারীর চেয়ে তার স্ত্রীর আয় বেশি"
vector = "bn_glove.300d.txt"
output = tokr.glove_based(text, vector_path=vector, sen_n=5, word_n=5)
print(output)
# Out:
# 'চেয়ে'
# 'আয়'
# ['এমপি নিজাম হাজারীর চেয়ে তার স্ত্রীর আয় বেশি', 'এমপি নিজাম হাজারীর চেয়ে তার মায়ের আয় বেশি', 'এমপি নিজাম হাজারীর চেয়ে তার নেছা আয় বেশি', 'এমপি নিজাম হাজারীর চেয়ে তার মনোয়ারা আয় বেশি', 'এমপি নিজাম হাজারীর চেয়ে তার জমিলা আয় বেশি', 'এমপি নিজাম হাজারীর চেয়ে তার স্ত্রীর আয় বেশি', '♠ নিজাম হাজারীর চেয়ে তার স্ত্রীর আয় বেশি', 'মেম্বারদের নিজাম হাজারীর চেয়ে তার স্ত্রীর আয় বেশি', 'রুশনারা নিজাম হাজারীর চেয়ে তার স্ত্রীর আয় বেশি', 'সংসদসদস্য নিজাম হাজারীর চেয়ে তার স্ত্রীর আয় বেশি', 'এমপি নিজাম হাজারীর চেয়ে তার স্ত্রীর আয় বেশি', 'এমপি নিজাম হাজারীর চেয়ে তার মায়ের আয় বেশি', 'এমপি নিজাম হাজারীর চেয়ে তার নেছা আয় বেশি', 'এমপি নিজাম হাজারীর চেয়ে তার মনোয়ারা আয় বেশি', 'এমপি নিজাম হাজারীর চেয়ে তার জমিলা আয় বেশি']

# %% [markdown]
# Back Translation

# %%
from bnaug.sentence import BackTranslation

bt = BackTranslation()
text = """স্রেফ দু’টি টুইটেই সোশ্যাল মিডিয়ায় তোলপাড় ফেলে দিয়েছেন সিদ্ধার্থ সূর্যনারায়ণ। এমন দু’টি কথা তিনি বলেছেন, যা একইসঙ্গে সমাজ এবং সিনেমাকে একসুতোয় বেঁধেছে।\nমহিলাদের পিছু নেওয়া, তাঁদের উত্ত্যক্ত করা ঘিরে আলোচনা চলছে সর্বত্র। চেন্নাইয়ের রাস্তায় দিনেদুপুরে এক মহিলাকে খুন করা হয়েছে সম্প্রতি। নারীসুরক্ষা নিয়ে চলছে আলোচনা, মত বিনিময়। ঠিক এইরকম একটি পরিস্থিতিতে সিদ্ধার্থের জোড়া টুইট আত্মসমালোচনার সামিল। কীভাবে এই সামাজিক অভিশাপের নেপথ্যে সিনেমারও দায় থেকে যায়, তা স্পষ্টভাষায় তুলে ধরেছেন সিদ্ধার্থ। কোনও রাখঢাক না-করেই তিনি বলেছেন, সিনেমায় এমনটি একটি স্বপ্ন ফেরি করার চেষ্টা চলে, যা সম্পূর্ণ ভুল।\nকীভাবে?\n\nসিদ্ধার্থ তুলে এনেছেন ভারতীয় ছবিতে বহু-ব্যবহৃত এবং জনপ্রিয় একটি সিকোয়েন্সের প্রসঙ্গ। যেখানে নায়িকার পিছু নিতে দেখা যায় নায়ককে। পরিণতি? দেখানো হয়, প্রাথমিকভাবে বিরক্ত হলেও, সময়ক্রমে নায়িকা অনিবার্যভাবে নায়কের প্রেমে হাবুডুবু খেতে শুরু করেছেন। এই ধরনের দৃশ্য এত বেশি এবং এতভাবে ব্যবহার করা হয়েছে, যা কোথাও গিয়ে পিছু নেওয়া ব্যাপারটিতে একটি সিলমোহর দিয়েছে বলে মনে করেন সিদ্ধার্থ। তাঁর সাফ কথা, সমাজের প্রতি সকলের একটি ‘‘সামগ্রিক দায়বদ্ধতা’’ রয়েছে। প্রথম টুইটে সিদ্ধার্থ লিখেছেন, ‘‘দীর্ঘদিন ধরে আমরা আমাদের ছবিতে একটি ভয়ঙ্কর স্বপ্ন ফেরি করে চলেছি। সেটা হল, যে কোনও মহিলাকে পছন্দ হলেই তাঁর পিছু নিতে শুরু করেন একজন পুরুষ। এই পরিস্থিতির অবশ্যই পরিবর্তন করতে হবে।’’\nএখানেই থামেননি দক্ষিণের এই অভিনেতা। দ্বিতীয় টুইটটি আরও বিস্ফোরক। লিখেছেন, ‘‘আমাদের ছবিতে কোনও মহিলা যখন কোনও পুরুষের পিছু নেন, তখন তিনি খলনায়িকা। কিন্তু একজন পুরুষ কোনও মহিলার পিছু নিলে তিনি নায়ক। এটি একটি জটিল আলোচনা। কিন্তু এই আলোচনাটি হওয়া প্রয়োজন।’’\nকী মনে হয়? কোনও প্রশংসাই সম্ভবত যথেষ্ট নয়।"""
output = bt.get_augmented_sentences(text)
print(output)
# Out:
# [' এই ঘটনায়, সিদ্ধার্থের একটি টুইট, যা কিনা এক সময় এক ভয়াবহ ঘটনার জন্ম দেয়, তা হচ্ছে, এই ঘটনায়, এক পুরুষ এক নারীর পিছু নেয়, আর এই ঘটনা এক জটিল পরিস্থিতির সৃষ্টি করে।']

# %%
from bnaug.sentence import TextGeneration

tg = TextGeneration()
text = text
output = tg.parapharse_generation(text)
print(output)
# Out:
# config.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.15k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation_utils.py:1359: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 20 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# [' তার প্রথম টুইটে, সিদ্ধার্থ পরিষ্কারভাবে বলেছেন যে এই ধরনের দৃশ্য অনেক দিন ধরে চলছে, যখন একজন']

# %% [markdown]
# ### **Sentiment Analysis Data Augmentation**

# %%
# !git clone https://github.com/mahedishato/Bangla-Sentiment-Analysis.git
# Out:
# Cloning into 'Bangla-Sentiment-Analysis'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 17 (delta 2), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (17/17), 2.50 MiB | 5.01 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
import pandas as pd, numpy as np, plotly.express as px, seaborn as sns, re
from sklearn.model_selection import train_test_split
import keras

# %%
from keras.preprocessing.text import Tokenizer

# %%
def text_to_word_list(text):
    text = text.split()
    return text

def replace_strings(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           u"\u00C0-\u017F"          #latin
                           u"\u2000-\u206F"          #generalPunctuations

                           "]+", flags=re.UNICODE)
    english_pattern=re.compile('[a-zA-Z0-9]+', flags=re.I)
    #latin_pattern=re.compile('[A-Za-z\u00C0-\u00D6\u00D8-\u00f6\u00f8-\u00ff\s]*',)

    text=emoji_pattern.sub(r'', text)
    text=english_pattern.sub(r'', text)

    return text

def remove_punctuations(my_str):
    # define punctuation
    punctuations = '''````£|¢|Ñ+-*/=EROero৳০১২৩৪৫৬৭৮৯012–34567•89।!()-[]{};:'"“\’,<>./?@#$%^&*_~‘—॥”‰⚽️✌�￰৷￰'''

    no_punct = ""
    for char in my_str:
        if char not in punctuations:
            no_punct = no_punct + char

    # display the unpunctuated string
    return no_punct



def joining(text):
    out=' '.join(text)
    return out

def preprocessing(text):
    out=remove_punctuations(replace_strings(text))
    return out

# %%
df = pd.read_excel('/content/Bangla-Sentiment-Analysis/predicted_unsupervised_sentiment.xlsx')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0           0         NaN         NaN
# 1           1         NaN         NaN
# 2           2         NaN         NaN
# 3           3         NaN         NaN
# 4           4         NaN         NaN
#
#                                             sentence  sentiment
# 0                            ওয়ও আমি গর্বিত বাঙ্গালি          1
# 1  বাংলাদেশ এর কিছু মানুষ নিজে কিছু করতে পারবেনা ...          0
# 2                                 রামোসের ঘুম আসে না          0
# 3                  কোহলির প্রতি শ্রদ্ধা হারিয়ে ফেলছি          1
# 4  থ্যাঙ্ক ইউ মাছরাঙ্গা টেলিভিশনকিন্তু ছাপোষা আন্...          0

# %%
df.reset_index(drop=True, inplace=True)
df['sentence'] = df.sentence.apply(lambda x: preprocessing(str(x)))

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0           0         NaN         NaN
# 1           1         NaN         NaN
# 2           2         NaN         NaN
# 3           3         NaN         NaN
# 4           4         NaN         NaN
#
#                                             sentence  sentiment
# 0                            ওয়ও আমি গর্বিত বাঙ্গালি          1
# 1  বাংলাদেশ এর কিছু মানুষ নিজে কিছু করতে পারবেনা ...          0
# 2                                 রামোসের ঘুম আসে না          0
# 3                  কোহলির প্রতি শ্রদ্ধা হারিয়ে ফেলছি          1
# 4  থ্যাঙ্ক ইউ মাছরাঙ্গা টেলিভিশনকিন্তু ছাপোষা আন্...          0

# %%
display(df)

# %%
seed_value = 42
df_sampled = df.sample(frac=0.3, random_state=seed_value)

# %%
df_sampled
# Out:
#       Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 2929        2929         NaN         NaN
# 217          217         NaN         NaN
# 3213        3213         NaN         NaN
# 5571        5571         NaN         NaN
# 1543        1543         NaN         NaN
# ...          ...         ...         ...
# 4597        4597         NaN         NaN
# 3488        3488         NaN         NaN
# 1684        1684         NaN         NaN
# 1586        1586         NaN         NaN
# 4310        4310         NaN         NaN
#
#                                                sentence  sentiment
# 2929                                      পরবা কোড করবা          0
# 217                 গিলমটস পাথীদের উড়ে চলার মনোরম দৃশ্য          1
# 3213  এখন কার মেয়েরা তু পায়ে কাছা কাছি যেতে চায় না অ...          0
# 5571  আপরাধী ধরেয় কোন বিচার হয়েতেছে আর আপরাধী খুজতে ...          0
# 1543  আজকাল স্বল্প প্রশিক্ষন আর অভিজ্ঞতা নিয়েই হিমল...          1
# ...                                                 ...        ...
# 4597  কিন্তু সিম নিবন্ধন না করেই যদি শুনি আমার সিম অ...          0
# 3488  মুস্তাফিজ হাজার ও আলো জ্বালিয়ে দাওসমস্ত পৃথিবী...          1
# 1684  সার খাতে গ্যাসের মূল্য বৃদ্ধির ফলে কৃষককে যে স...          0
# 1586  জঙ্গিদের চামড়া তুলে নেব আমরা এরা হচ্ছে পাকিস্ত...          0
# 4310                         আধুনিক যুগে পুরোনো নাম ছিঃ          0
#
# [1996 rows x 5 columns]

# %%
from bnaug.sentence import TokenReplacement
def text_augmentation(text):
  tokr = TokenReplacement()
  model = "bangla_word2vec/bnwiki_word2vec.model"
  output = tokr.word2vec_based(text, model=model, sen_n=5, word_n=5)
  trimmed_output = output[:5]
  return trimmed_output

# %%
df_sampled['sentence']
# Out:
# 2929                                        পরবা কোড করবা
# 217                   গিলমটস পাথীদের উড়ে চলার মনোরম দৃশ্য
# 3213    এখন কার মেয়েরা তু পায়ে কাছা কাছি যেতে চায় না অ...
# 5571    আপরাধী ধরেয় কোন বিচার হয়েতেছে আর আপরাধী খুজতে ...
# 1543    আজকাল স্বল্প প্রশিক্ষন আর অভিজ্ঞতা নিয়েই হিমল...
#                               ...
# 4597    কিন্তু সিম নিবন্ধন না করেই যদি শুনি আমার সিম অ...
# 3488    মুস্তাফিজ হাজার ও আলো জ্বালিয়ে দাওসমস্ত পৃথিবী...
# 1684    সার খাতে গ্যাসের মূল্য বৃদ্ধির ফলে কৃষককে যে স...
# 1586    জঙ্গিদের চামড়া তুলে নেব আমরা এরা হচ্ছে পাকিস্ত...
# 4310                           আধুনিক যুগে পুরোনো নাম ছিঃ
# Name: sentence, Length: 1996, dtype: object

# %%
# Apply text_augmentation to each row in 'sentence' column
augmented_sentences = df_sampled['sentence'].apply(lambda x: text_augmentation(x))

# Flatten the list of lists
flattened_sentences = [item for sublist in augmented_sentences for item in sublist]

# Create a new DataFrame with original and augmented sentences
new_data = {'original_sentence': flattened_sentences, 'sentiment': df_sampled['sentiment'].repeat(5).tolist()}
new_df = pd.DataFrame(new_data)
# Out:
# "Key 'পরবা' not present in vocabulary"
# "Key 'করবা' not present in vocabulary"
# "Key 'পরবা' not present in vocabulary"
# "Key 'পরবা' not present in vocabulary"
# "Key 'পরবা' not present in vocabulary"
# "Key 'উড়ে' not present in vocabulary"
# "Key 'পাথীদের' not present in vocabulary"
# "Key 'উড়ে' not present in vocabulary"
# "Key 'চায়' not present in vocabulary"
# "Key 'আপরাধী' not present in vocabulary"
# "Key 'দিয়াছে' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'হারামির' not present in vocabulary"
# "Key 'নিয়ে' not present in vocabulary"
# "Key 'আত্নঘাতি' not present in vocabulary"
# "Key 'দিয়ে' not present in vocabulary"
# "Key 'দিয়ে' not present in vocabulary"
# "Key 'এক্কেবারে' not present in vocabulary"
# "Key 'গিয়ে' not present in vocabulary"
# "Key 'টয়লেটে' not present in vocabulary"
# "Key 'মোকছেদ' not present in vocabulary"
# "Key 'কমেন্ট' not present in vocabulary"
# "Key 'চিপায়' not present in vocabulary"
# "Key 'চিপায়' not present in vocabulary"
# "Key 'নিরাপরাধ' not present in vocabulary"
# "Key 'নবিনুররে' not present in vocabulary"
# "Key 'নায়কদের' not present in vocabulary"
# "Key 'দিয়ে' not present in vocabulary"
# "Key 'জয়' not present in vocabulary"
# "Key 'জয়' not present in vocabulary"
# "Key 'জয়' not present in vocabulary"
# "Key 'জয়' not present in vocabulary"
# "Key 'জয়' not present in vocabulary"
# "Key 'বায়োমেট্রিক' not present in vocabulary"
# "Key 'ধুর' not present in vocabulary"
# "Key 'ধুর' not present in vocabulary"
# "Key 'ধুর' not present in vocabulary"
# "Key 'ছুঁয়ে' not present in vocabulary"
# "Key 'নেওয়ার' not present in vocabulary"
# "Key 'লিখেছিস' not present in vocabulary"
# "Key 'লিখেছিস' not present in vocabulary"
# "Key 'তুমার' not present in vocabulary"
# "Key 'দিছে' not present in vocabulary"
# "Key 'করতামনাআমি' not present in vocabulary"
# "Key 'ফুলিশ' not present in vocabulary"
# "Key 'বুঝলামনা' not present in vocabulary"
# "Key 'পুরাই' not present in vocabulary"
# "Key 'পুরাই' not present in vocabulary"
# "Key 'পুরাই' not present in vocabulary"
# "Key 'পুরাই' not present in vocabulary"
# "Key 'পারিআজ' not present in vocabulary"
# "Key 'ভয়াবহ' not present in vocabulary"
# "Key 'দিয়েছে' not present in vocabulary"
# "Key 'হয়নিআড়ালে' not present in vocabulary"
# "Key 'র্কোস' not present in vocabulary"
# "Key 'শাস্ত্রীয়' not present in vocabulary"
# "Key 'গুলোয়' not present in vocabulary"
# "Key 'কুত্তায়' not present in vocabulary"
# "Key 'দিয়ে' not present in vocabulary"
# "Key 'করবেনজনগনকে' not present in vocabulary"
# "Key 'দলীয়দের' not present in vocabulary"
# "Key 'দলীয়দের' not present in vocabulary"
# "Key 'মায়া' not present in vocabulary"
# "Key 'ঊদারতা' not present in vocabulary"
# "Key 'জ্বালায়' not present in vocabulary"
# "Key 'গেলমনে' not present in vocabulary"
# "Key 'গেলমনে' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'মেয়ের' not present in vocabulary"
# "Key 'বিয়ে' not present in vocabulary"
# "Key 'মেয়ের' not present in vocabulary"
# "Key 'হালার' not present in vocabulary"
# "Key 'ভীড়' not present in vocabulary"
# "Key 'বাড়ের' not present in vocabulary"
# "Key 'যায়' not present in vocabulary"
# "Key 'মায়ার' not present in vocabulary"
# "Key 'পাগলামী' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'পাগলামী' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'দিয়ে' not present in vocabulary"
# "Key 'রায়কে' not present in vocabulary"
# "Key 'জয়' not present in vocabulary"
# "Key 'জয়' not present in vocabulary"
# "Key 'জয়' not present in vocabulary"
# "Key 'দ্বারিয়েছে' not present in vocabulary"
# "Key 'হারামি' not present in vocabulary"
# "Key 'হারামি' not present in vocabulary"
# "Key 'হারামি' not present in vocabulary"
# "Key 'হারামি' not present in vocabulary"
# "Key 'হারামি' not present in vocabulary"
# "Key 'বিয়েতে' not present in vocabulary"
# "Key 'বিয়েতে' not present in vocabulary"
# "Key 'মামনি' not present in vocabulary"
# "Key 'চিন্তায়' not present in vocabulary"
# "Key 'চিন্তায়' not present in vocabulary"
# "Key 'ভরেনা' not present in vocabulary"
# "Key 'হাসালে' not present in vocabulary"
# "Key 'হাসালে' not present in vocabulary"
# "Key 'হাসালে' not present in vocabulary"
# "Key 'চেয়েও' not present in vocabulary"
# "Key 'ভারতশালা' not present in vocabulary"
# "Key 'বেঈমানের' not present in vocabulary"
# "Key 'ভারতশালা' not present in vocabulary"
# "Key 'বেঈমানের' not present in vocabulary"
# "Key 'কোথায়' not present in vocabulary"
# "Key 'অপরাজেয়' not present in vocabulary"
# "Key 'অপরাজেয়' not present in vocabulary"
# "Key 'অপরাজেয়' not present in vocabulary"
# "Key 'অপরাজেয়' not present in vocabulary"
# "Key 'অপরাজেয়' not present in vocabulary"
# "Key 'চর্মনাই' not present in vocabulary"
# "Key 'র্যাবের' not present in vocabulary"
# "Key 'যাওয়া' not present in vocabulary"
# "Key 'যাওয়া' not present in vocabulary"
# "Key 'হারিয়ে' not present in vocabulary"
# "Key 'গানটার' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'ফেলসি' not present in vocabulary"
# "Key 'বিশ্ববিদ্যালয়ের' not present in vocabulary"
# "Key 'পাখিরে' not present in vocabulary"
# "Key 'হাসিয়া' not present in vocabulary"
# "Key 'দিয়ে' not present in vocabulary"
# "Key 'বানানোও' not present in vocabulary"
# "Key 'আলহামদুলিল্লা' not present in vocabulary"
# "Key 'আলহামদুলিল্লা' not present in vocabulary"
# "Key 'সম্পক্তি' not present in vocabulary"
# "Key 'সরকারিজনগনের' not present in vocabulary"
# "Key 'আয়' not present in vocabulary"
# "Key 'গেলএই' not present in vocabulary"
# "Key 'রায়গঞ্জ' not present in vocabulary"
# "Key 'কামিয়েছে' not present in vocabulary"
# "Key 'খুবে' not present in vocabulary"
# "Key 'দিয়ে' not present in vocabulary"
# "Key 'দিয়ে' not present in vocabulary"
# "Key 'কোথায়' not present in vocabulary"
# "Key 'কোথায়' not present in vocabulary"
# "Key 'কোথায়' not present in vocabulary"
# "Key 'কোথায়' not present in vocabulary"
# "Key 'উদ্যেক্তাকে' not present in vocabulary"
# "Key 'উদ্যেক্তাকে' not present in vocabulary"
# "Key 'উদ্যেক্তাকে' not present in vocabulary"
# "Key 'নিয়ে' not present in vocabulary"
# "Key 'হয়ে' not present in vocabulary"
# "Key 'মেয়েরা' not present in vocabulary"
# "Key 'ভালসেটা' not present in vocabulary"
# "Key 'ভালসেটা' not present in vocabulary"
# "Key 'নিয়েছে' not present in vocabulary"
# "Key 'কুছু' not present in vocabulary"
# "Key 'ইন্ডিয়ার' not present in vocabulary"
# "Key 'ওয়ানডে' not present in vocabulary"
# "Key 'মালটাকে' not present in vocabulary"
# "Key 'উড়িয়ে' not present in vocabulary"
# "Key 'খাওয়াতে' not present in vocabulary"
# "Key 'খাওয়াতে' not present in vocabulary"
# "Key 'বাবাদেরও' not present in vocabulary"
# "Key 'মেয়েদেরকে' not present in vocabulary"
# "Key 'মেয়েদেরকে' not present in vocabulary"
# "Key 'চায়' not present in vocabulary"
# "Key 'অস্ট্রেলিয়াতে' not present in vocabulary"
# "Key 'পরীক্ষাস্থল' not present in vocabulary"
# "Key 'নাড়িয়ে' not present in vocabulary"
# "Key 'ইন্ডিয়ান' not present in vocabulary"
# "Key 'পালায়' not present in vocabulary"
# "Key 'নেওয়া' not present in vocabulary"
# "Key 'থাকেননা' not present in vocabulary"
# "Key 'আবাল' not present in vocabulary"
# "Key 'থামাবার' not present in vocabulary"
# "Key 'মায়েরটাও' not present in vocabulary"
# "Key 'মায়েরটাও' not present in vocabulary"
# "Key 'অব্যবহার' not present in vocabulary"
# "Key 'হয়নিএরকম' not present in vocabulary"
# "Key 'কয়টার' not present in vocabulary"
# "Key 'কয়টার' not present in vocabulary"
# "Key 'কয়টার' not present in vocabulary"
# "Key 'কয়টার' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'বেইমানিই' not present in vocabulary"
# "Key 'কোরছো' not present in vocabulary"
# "Key 'মেয়েরা' not present in vocabulary"
# "Key 'মেয়েরা' not present in vocabulary"
# "Key 'শক্তের' not present in vocabulary"
# "Key 'শক্তের' not present in vocabulary"
# "Key 'শক্তের' not present in vocabulary"
# "Key 'ভালাবাসি' not present in vocabulary"
# "Key 'ভালাবাসি' not present in vocabulary"
# "Key 'ভালাবাসি' not present in vocabulary"
# "Key 'ভালাবাসি' not present in vocabulary"
# "Key 'ভালাবাসি' not present in vocabulary"
# "Key 'হয়ে' not present in vocabulary"
# "Key 'বড়' not present in vocabulary"
# "Key 'ছিঃ' not present in vocabulary"
# "Key 'ছিঃ' not present in vocabulary"
# "Key 'ছিঃ' not present in vocabulary"
# "Key 'ছিঃ' not present in vocabulary"
# "Key 'ছিঃ' not present in vocabulary"
# "Key 'মায়াজাল' not present in vocabulary"
# "Key 'মায়াজাল' not present in vocabulary"
# "Key 'হেয়' not present in vocabulary"
# "Key 'গলায়' not present in vocabulary"
# "Key 'ব্যাটিংয়ের' not present in vocabulary"
# "Key 'যায়' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'হুদাই' not present in vocabulary"
# "Key 'নিয়াই' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'পৃথিবীতোমার' not present in vocabulary"
# "Key 'ভাইয়ের' not present in vocabulary"
# "Key 'পৃথিবীতোমার' not present in vocabulary"
# "Key 'বার্সালোনা' not present in vocabulary"
# "Key 'জানেকি' not present in vocabulary"
# "Key 'এতক্ষন' not present in vocabulary"
# "Key 'এতক্ষন' not present in vocabulary"
# "Key 'ছোড়া' not present in vocabulary"
# "Key 'আশকোনা' not present in vocabulary"
# "Key 'কুপিয়ে' not present in vocabulary"
# "Key 'হওক' not present in vocabulary"
# "Key 'প্রয়োগ' not present in vocabulary"
# "Key 'প্রয়োজন' not present in vocabulary"
# "Key 'নাকিআজব' not present in vocabulary"
# "Key 'বায়োমেট্রিক' not present in vocabulary"
# "Key 'লংসুলতান' not present in vocabulary"
# "Key 'শুয়োরের' not present in vocabulary"
# "Key 'শুয়োরের' not present in vocabulary"
# "Key 'দয়া' not present in vocabulary"
# "Key 'আড্ডাখানা' not present in vocabulary"
# "Key 'বোধোদয়' not present in vocabulary"
# "Key 'প্রোশিক্ষন' not present in vocabulary"
# "Key 'প্রোশিক্ষন' not present in vocabulary"
# "Key 'প্রোশিক্ষন' not present in vocabulary"
# "Key 'অশ্বীন' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'যায়' not present in vocabulary"
# "Key 'ছড়ায়' not present in vocabulary"
# "Key 'হিজড়ারা' not present in vocabulary"
# "Key 'হিজড়ারা' not present in vocabulary"
# "Key 'ছড়ায়' not present in vocabulary"
# "Key 'প্রাচিরের' not present in vocabulary"
# "Key 'নিযত' not present in vocabulary"
# "Key 'তাইলে' not present in vocabulary"
# "Key 'জানেনাআবার' not present in vocabulary"
# "Key 'পায়' not present in vocabulary"
# "Key 'চলতেছে' not present in vocabulary"
# "Key 'আখেরে' not present in vocabulary"
# "Key 'চলতেছে' not present in vocabulary"
# "Key 'হয়েছিল' not present in vocabulary"
# "Key 'বারসেলোনার' not present in vocabulary"
# "Key 'ট্রপি' not present in vocabulary"
# "Key 'প্রর্দশনির' not present in vocabulary"
# "Key 'ক্ষন' not present in vocabulary"
# "Key 'খেলুয়াড়' not present in vocabulary"
# "Key 'ক্যয়দিন' not present in vocabulary"
# "Key 'ক্যয়দিন' not present in vocabulary"
# "Key 'শান্তনা' not present in vocabulary"
# "Key 'শান্তনা' not present in vocabulary"
# "Key 'শান্তনা' not present in vocabulary"
# "Key 'দেয়ার' not present in vocabulary"
# "Key 'কতক্ষন' not present in vocabulary"
# "Key 'কদু' not present in vocabulary"
# "Key 'কদু' not present in vocabulary"
# "Key 'ডাকাতকে' not present in vocabulary"
# "Key 'আমানতদারী' not present in vocabulary"
# "Key 'আমানতদারী' not present in vocabulary"
# "Key 'ভিডিওটা' not present in vocabulary"
# "Key 'তোভাল' not present in vocabulary"
# "Key 'তোভাল' not present in vocabulary"
# "Key 'ঘুমাওনইলে' not present in vocabulary"
# "Key 'পাওয়ার' not present in vocabulary"
# "Key 'টাকারে' not present in vocabulary"
# "Key 'টাকারে' not present in vocabulary"
# "Key 'সারাবিশ্ব' not present in vocabulary"
# "Key 'সারাবিশ্ব' not present in vocabulary"
# "Key 'বুঝলাম' not present in vocabulary"
# "Key 'প্যচ' not present in vocabulary"
# "Key 'কেচু' not present in vocabulary"
# "Key 'বাপকেও' not present in vocabulary"
# "Key 'বাপকেও' not present in vocabulary"
# "Key 'ছাড়েনা' not present in vocabulary"
# "Key 'চেয়ে' not present in vocabulary"
# "Key 'হয়ে' not present in vocabulary"
# "Key 'ইন্ডিয়ার' not present in vocabulary"
# "Key 'রহস্যময়তা' not present in vocabulary"
# "Key 'রহস্যময়তা' not present in vocabulary"
# "Key 'চালিয়ে' not present in vocabulary"
# "Key 'যাওআমরা' not present in vocabulary"
# "Key 'হেটার' not present in vocabulary"
# "Key 'শ্রেয়' not present in vocabulary"
# "Key 'ভিস্কাবার্সা' not present in vocabulary"
# "Key 'আছেস্যালুট' not present in vocabulary"
# "Key 'কথায়' not present in vocabulary"
# "Key 'অমানবিকতার' not present in vocabulary"
# "Key 'হওয়ার' not present in vocabulary"
# "Key 'নাবার্সেলোনা' not present in vocabulary"
# "Key 'প্রিয়' not present in vocabulary"
# "Key 'বৈষম্যটা' not present in vocabulary"
# "Key 'ভ্যাটের' not present in vocabulary"
# "Key 'ভ্যাটের' not present in vocabulary"
# "Key 'বড়' not present in vocabulary"
# "Key 'চেয়ে' not present in vocabulary"
# "Key 'গায়ে' not present in vocabulary"
# "Key 'ভারতীয়' not present in vocabulary"
# "Key 'সেগুলারে' not present in vocabulary"
# "Key 'দিয়ে' not present in vocabulary"
# "Key 'পারফর্মমেন্স' not present in vocabulary"
# "Key 'পারফর্মমেন্স' not present in vocabulary"
# "Key 'ধান্দাবাজ' not present in vocabulary"
# "Key 'ধান্দাবাজ' not present in vocabulary"
# "Key 'ধান্দাবাজ' not present in vocabulary"
# "Key 'ধান্দাবাজ' not present in vocabulary"
# "Key 'মন্ত্রীরাও' not present in vocabulary"
# "Key 'সুখশান্তি' not present in vocabulary"
# "Key 'সুখশান্তি' not present in vocabulary"
# "Key 'টারে' not present in vocabulary"
# "Key 'পড়ে' not present in vocabulary"
# "Key 'পারছিনাক্যাপশনটা' not present in vocabulary"
# "Key 'লিখসস' not present in vocabulary"
# "Key 'দিয়ে' not present in vocabulary"
# "Key 'দিয়েছিলেন' not present in vocabulary"
# "Key 'চালাবেনআল্লাহ' not present in vocabulary"
# "Key 'জানোওয়ার' not present in vocabulary"
# "Key 'নয়' not present in vocabulary"
# "Key 'নয়' not present in vocabulary"
# "Key 'যায়' not present in vocabulary"
# "Key 'জাতীয়' not present in vocabulary"
# "Key 'জাতীয়' not present in vocabulary"
# "Key 'জাতীয়' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'নাশুধু' not present in vocabulary"
# "Key 'বড়' not present in vocabulary"
# "Key 'নয়' not present in vocabulary"
# "Key 'ছাড়া' not present in vocabulary"
# "Key 'চায়' not present in vocabulary"
# "Key 'বড়ই' not present in vocabulary"
# "Key 'বলিং' not present in vocabulary"
# "Key 'বলিং' not present in vocabulary"
# "Key 'জড়িতোদের' not present in vocabulary"
# "Key 'মূল্যায়ন' not present in vocabulary"
# "Key 'মূল্যায়ন' not present in vocabulary"
# "Key 'মূল্যায়ন' not present in vocabulary"
# "Key 'বার্সেলোনা' not present in vocabulary"
# "Key 'দেয়' not present in vocabulary"
# "Key 'প্রিমিয়ার' not present in vocabulary"
# "Key 'প্রিমিয়ার' not present in vocabulary"
# "Key 'প্রিমিয়ার' not present in vocabulary"
# "Key 'জম্ন' not present in vocabulary"
# "Key 'গরবে' not present in vocabulary"
# "Key 'সেলুট' not present in vocabulary"
# "Key 'ভঙ্গকারীদের' not present in vocabulary"
# "Key 'ভঙ্গকারীদের' not present in vocabulary"
# "Key 'প্রশ্রয়' not present in vocabulary"
# "Key 'সময়' not present in vocabulary"
# "Key 'সময়' not present in vocabulary"
# "Key 'সময়' not present in vocabulary"
# "Key 'বেজন্মা' not present in vocabulary"
# "Key 'বেজন্মা' not present in vocabulary"
# "Key 'ঐগুলা' not present in vocabulary"
# "Key 'ঐগুলা' not present in vocabulary"
# "Key 'বেজন্মা' not present in vocabulary"
# "Key 'নয়' not present in vocabulary"
# "Key 'সৌদিআরব' not present in vocabulary"
# "Key 'সৌদিআরব' not present in vocabulary"
# "Key 'মামলায়' not present in vocabulary"
# "Key 'মামলায়' not present in vocabulary"
# "Key 'মামলায়' not present in vocabulary"
# "Key 'বিপ্লবি' not present in vocabulary"
# "Key 'হৃদয়' not present in vocabulary"
# "Key 'সাইফউদ্দিনকে' not present in vocabulary"
# "Key 'বেহায়াপনা' not present in vocabulary"
# "Key 'ফ্লুইং' not present in vocabulary"
# "Key 'শিওর' not present in vocabulary"
# "Key 'দেরকেও' not present in vocabulary"
# "Key 'স্রৃতি' not present in vocabulary"
# "Key 'পরছি' not present in vocabulary"
# "Key 'কোন' not present in vocabulary"
# "Key 'অপুর্ণতা' not present in vocabulary"
# "Key 'খোঁড়াখুঁড়ি' not present in vocabulary"
# "Key 'মিডিয়াতে' not present in vocabulary"
# "Key 'পাওয়া' not present in vocabulary"
# "Key 'সাজেশানের' not present in vocabulary"
# "Key 'সাজেশানের' not present in vocabulary"
# "Key 'হয়েছিল' not present in vocabulary"
# "Key 'কিসেরলজ্জা' not present in vocabulary"
# "Key 'প্রথিবী' not present in vocabulary"
# "Key 'বানায়' not present in vocabulary"
# "Key 'বানায়' not present in vocabulary"
# "Key 'জন্যআশা' not present in vocabulary"
# "Key 'শেয়ার' not present in vocabulary"
# "Key 'এডমিনদের' not present in vocabulary"
# "Key 'আজাইরা' not present in vocabulary"
# "Key 'আজাইরা' not present in vocabulary"
# "Key 'আজাইরা' not present in vocabulary"
# "Key 'জয়' not present in vocabulary"
# "Key 'জয়' not present in vocabulary"
# "Key 'জয়' not present in vocabulary"
# "Key 'অভাবনীয়' not present in vocabulary"
# "Key 'জয়' not present in vocabulary"
# "Key 'চখের' not present in vocabulary"
# "Key 'চায়' not present in vocabulary"
# "Key 'পড়ি' not present in vocabulary"
# "Key 'পড়ি' not present in vocabulary"
# "Key 'জায়গায়' not present in vocabulary"
# "Key 'শাস্তিটা' not present in vocabulary"
# "Key 'শাস্তিটা' not present in vocabulary"
# "Key 'সিনবাদ' not present in vocabulary"
# "Key 'ভাঙলো' not present in vocabulary"
# "Key 'মহিলারও' not present in vocabulary"
# "Key 'সাবাশ' not present in vocabulary"
# "Key 'বিয়াই' not present in vocabulary"
# "Key 'অনিতো' not present in vocabulary"
# "Key 'হয়ে' not present in vocabulary"
# "Key 'কেন্দ্রীকই' not present in vocabulary"
# "Key 'বুঝবি' not present in vocabulary"
# "Key 'প্রিয়' not present in vocabulary"
# "Key 'প্রায়ুথ' not present in vocabulary"
# "Key 'করতেছি' not present in vocabulary"
# "Key 'পিছিয়ে' not present in vocabulary"
# "Key 'প্রিয়' not present in vocabulary"
# "Key 'নেইএকটু' not present in vocabulary"
# "Key 'এখুনি' not present in vocabulary"
# "Key 'অযোগ্য' not present in vocabulary"
# "Key 'মন্ত্রিরা' not present in vocabulary"
# "Key 'ওচিত' not present in vocabulary"
# "Key 'ওচিত' not present in vocabulary"
# "Key 'হওয়া' not present in vocabulary"
# "Key 'মেয়ে' not present in vocabulary"
# "Key 'কাছেতখন' not present in vocabulary"
# "Key 'কাছেতখন' not present in vocabulary"
# "Key 'ঠকবেতবে' not present in vocabulary"
# "Key 'জীবন্টাত' not present in vocabulary"
# "Key 'জীবন্টাত' not present in vocabulary"
# "Key 'জীবন্টাত' not present in vocabulary"
# "Key 'জীবন্টাত' not present in vocabulary"
# "Key 'ম্যাকগাইভাররবিনহুড' not present in vocabulary"
# "Key 'বিশ্ববিদ্যালয়' not present in vocabulary"
# "Key 'এর্দোগান' not present in vocabulary"
# "Key 'গনমানুষের' not present in vocabulary"
# "Key 'গনমানুষের' not present in vocabulary"
# "Key 'গনমানুষের' not present in vocabulary"
# "Key 'দিয়েছি' not present in vocabulary"
# "Key 'দিয়েছি' not present in vocabulary"
# "Key 'এফসিবি' not present in vocabulary"
# "Key 'এফসিবি' not present in vocabulary"
# "Key 'তাসকিনকেই' not present in vocabulary"
# "Key 'এগিয়ে' not present in vocabulary"
# "Key 'সরাসরিবলতাম' not present in vocabulary"
# "Key 'বালের' not present in vocabulary"
# "Key 'মিয়া' not present in vocabulary"
# "Key 'মানুষেরবিশেষ' not present in vocabulary"
# "Key 'মানুষেরবিশেষ' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'নেও্যার' not present in vocabulary"
# "Key 'জয়' not present in vocabulary"
# "Key 'বাংলাদেকে' not present in vocabulary"
# "Key 'আবাও' not present in vocabulary"
# "Key 'ব্যাবস্থাপত্র' not present in vocabulary"
# "Key 'দিয়ে' not present in vocabulary"
# "Key 'দেখছিলাম' not present in vocabulary"
# "Key 'ব্যার্থতা' not present in vocabulary"
# "Key 'ব্যার্থতা' not present in vocabulary"
# "Key 'ব্যার্থতা' not present in vocabulary"
# "Key 'কোন' not present in vocabulary"
# "Key 'গায়ে' not present in vocabulary"
# "Key 'কথে' not present in vocabulary"
# "Key 'কথে' not present in vocabulary"
# "Key 'কথে' not present in vocabulary"
# "Key 'আরাফাতসানি' not present in vocabulary"
# "Key 'নিশ্চয়' not present in vocabulary"
# "Key 'নিশ্চয়' not present in vocabulary"
# "Key 'নিশ্চয়' not present in vocabulary"
# "Key 'বেয়াই' not present in vocabulary"
# "Key 'আপনেৱা' not present in vocabulary"
# "Key 'অামরা' not present in vocabulary"
# "Key 'অাপনে' not present in vocabulary"
# "Key 'নিয়ে' not present in vocabulary"
# "Key 'দেওয়া' not present in vocabulary"
# "Key 'জানোয়ারমানুষ' not present in vocabulary"
# "Key 'জানোয়ারমানুষ' not present in vocabulary"
# "Key 'চেয়ে' not present in vocabulary"
# "Key 'নিয়ে' not present in vocabulary"
# "Key 'দিয়ে' not present in vocabulary"
# "Key 'জোচ্চোরী' not present in vocabulary"
# "Key 'জোচ্চোরী' not present in vocabulary"
# "Key 'জোচ্চোরী' not present in vocabulary"
# "Key 'জোচ্চোরী' not present in vocabulary"
# "Key 'জোচ্চোরী' not present in vocabulary"
# "Key 'তৃতীয়' not present in vocabulary"
# "Key 'অমানুষের' not present in vocabulary"
# "Key 'মন্ত্রীত' not present in vocabulary"
# "Key 'ননতাঁরাও' not present in vocabulary"
# "Key 'কাপড়ে' not present in vocabulary"
# "Key 'সতর্কতাও' not present in vocabulary"
# "Key 'সপ্নেও' not present in vocabulary"
# "Key 'যায়' not present in vocabulary"
# "Key 'যায়' not present in vocabulary"
# "Key 'যায়গায়' not present in vocabulary"
# "Key 'নড়' not present in vocabulary"
# "Key 'তুরুস্ক' not present in vocabulary"
# "Key 'নয়' not present in vocabulary"
# "Key 'জিয়ার' not present in vocabulary"
# "Key 'নাইকো' not present in vocabulary"
# "Key 'উদ্ধক' not present in vocabulary"
# "Key 'উদ্ধক' not present in vocabulary"
# "Key 'ভ্যগো' not present in vocabulary"
# "Key 'পিরিয়ে' not present in vocabulary"
# "Key 'অাল্লাহ' not present in vocabulary"
# "Key 'ভাইয়া' not present in vocabulary"
# "Key 'ভাইয়া' not present in vocabulary"
# "Key 'ভাইয়া' not present in vocabulary"
# "Key 'দালালেরা' not present in vocabulary"
# "Key 'তোদে' not present in vocabulary"
# "Key 'মালাওনের' not present in vocabulary"
# "Key 'শাবাশ' not present in vocabulary"
# "Key 'শাবাশ' not present in vocabulary"
# "Key 'কথায়' not present in vocabulary"
# "Key 'কথায়' not present in vocabulary"
# "Key 'নাটকীয়তাএর' not present in vocabulary"
# "Key 'পায়েএকদিন' not present in vocabulary"
# "Key 'বিদেশেনিরাপদ' not present in vocabulary"
# "Key 'উননয়ন' not present in vocabulary"
# "Key 'তো' not present in vocabulary"
# "Key 'জমাচছে' not present in vocabulary"
# "Key 'বিয়েতে' not present in vocabulary"
# "Key 'হয়েছেন' not present in vocabulary"
# "Key 'পায়' not present in vocabulary"
# "Key 'পায়' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'মোড়লের' not present in vocabulary"
# "Key 'পড়ে' not present in vocabulary"
# "Key 'সময়' not present in vocabulary"
# "Key 'পায়' not present in vocabulary"
# "Key 'পড়বো' not present in vocabulary"
# "Key 'যায়' not present in vocabulary"
# "Key 'মাশরাফিকে' not present in vocabulary"
# "Key 'ফিস্টের' not present in vocabulary"
# "Key 'অগ্রীম' not present in vocabulary"
# "Key 'অন্যায়' not present in vocabulary"
# "Key 'অন্যায়' not present in vocabulary"
# "Key 'শুকরিয়া' not present in vocabulary"
# "Key 'শুকরিয়া' not present in vocabulary"
# "Key 'নয়' not present in vocabulary"
# "Key 'বাসতে' not present in vocabulary"
# "Key 'বাসতে' not present in vocabulary"
# "Key 'বাসতে' not present in vocabulary"
# "Key 'আমারো' not present in vocabulary"
# "Key 'আমারো' not present in vocabulary"
# "Key 'আমারো' not present in vocabulary"
# "Key 'বাড়ানোর' not present in vocabulary"
# "Key 'বাড়ানোর' not present in vocabulary"
# "Key 'খায়' not present in vocabulary"
# "Key 'খায়' not present in vocabulary"
# "Key 'সাব্বাস' not present in vocabulary"
# "Key 'পড়তে' not present in vocabulary"
# "Key 'পড়তে' not present in vocabulary"
# "Key 'তুচ্ছদুর্বলস্বার্থপর' not present in vocabulary"
# "Key 'অবক্ষয়' not present in vocabulary"
# "Key 'একসপ্রেস' not present in vocabulary"
# "Key 'হবপেইজ' not present in vocabulary"
# "Key 'হবপেইজ' not present in vocabulary"
# "Key 'যারাযদি' not present in vocabulary"
# "Key 'ফিরিয়ে' not present in vocabulary"
# "Key 'নাইযখন' not present in vocabulary"
# "Key 'এগুলু' not present in vocabulary"
# "Key 'এগুলু' not present in vocabulary"
# "Key 'সবসময়' not present in vocabulary"
# "Key 'থাকিস' not present in vocabulary"
# "Key 'শয়রের' not present in vocabulary"
# "Key 'শুয়রের' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'ক্লিয়ার' not present in vocabulary"
# "Key 'বাঁচিয়ে' not present in vocabulary"
# "Key 'যায়' not present in vocabulary"
# "Key 'হলধন্যবাদ' not present in vocabulary"
# "Key 'বড়' not present in vocabulary"
# "Key 'হলধন্যবাদ' not present in vocabulary"
# "Key 'দেওয়া' not present in vocabulary"
# "Key 'ধড়া' not present in vocabulary"
# "Key 'পড়বে' not present in vocabulary"
# "Key 'সন্ত্রাসি' not present in vocabulary"
# "Key 'পাওয়া' not present in vocabulary"
# "Key 'রেন্ডিয়ানরা' not present in vocabulary"
# "Key 'যাকআইসিসি' not present in vocabulary"
# "Key 'ষড়যন্ত্র' not present in vocabulary"
# "Key 'যাকআইসিসি' not present in vocabulary"
# "Key 'ওরাই' not present in vocabulary"
# "Key 'জন্মপরিচয়হীনরাই' not present in vocabulary"
# "Key 'নামিয়ে' not present in vocabulary"
# "Key 'নিআমরা' not present in vocabulary"
# "Key 'সোভিয়েতকে' not present in vocabulary"
# "Key 'ভারতীয়' not present in vocabulary"
# "Key 'সিরিয়াল' not present in vocabulary"
# "Key 'আপু' not present in vocabulary"
# "Key 'বিএনপিআফটার' not present in vocabulary"
# "Key 'চালিয়েছে' not present in vocabulary"
# "Key 'চালিয়েছে' not present in vocabulary"
# "Key 'জনপ্রিয়তা' not present in vocabulary"
# "Key 'তাসকিনে' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'করবাহাজার' not present in vocabulary"
# "Key 'আলহামদুলিল্লাহ্' not present in vocabulary"
# "Key 'আলহামদুলিল্লাহ্' not present in vocabulary"
# "Key 'আল্লাহু্' not present in vocabulary"
# "Key 'শালার' not present in vocabulary"
# "Key 'কায়েসের' not present in vocabulary"
# "Key 'দিয়ে' not present in vocabulary"
# "Key 'ঘুমিয়ে' not present in vocabulary"
# "Key 'মাদারচোদের' not present in vocabulary"
# "Key 'মাদারচোদের' not present in vocabulary"
# "Key 'দিয়ে' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'তালিকায়' not present in vocabulary"
# "Key 'সবচেয়ে' not present in vocabulary"
# "Key 'যায়' not present in vocabulary"
# "Key 'হয়ে' not present in vocabulary"
# "Key 'জগন্য' not present in vocabulary"
# "Key 'চিন্তায়' not present in vocabulary"
# "Key 'বাড়ির' not present in vocabulary"
# "Key 'বাড়ির' not present in vocabulary"
# "Key 'পড়ে' not present in vocabulary"
# "Key 'নেয়া' not present in vocabulary"
# "Key 'গোড়া' not present in vocabulary"
# "Key 'দিনটাই' not present in vocabulary"
# "Key 'শালায়' not present in vocabulary"
# "Key 'দেয়' not present in vocabulary"
# "Key 'দেয়' not present in vocabulary"
# "Key 'হয়েছে' not present in vocabulary"
# "Key 'অন্যায়ের' not present in vocabulary"
# "Key 'ট্যাস্ক' not present in vocabulary"
# "Key 'দাওদেশে' not present in vocabulary"
# "Key 'সময়' not present in vocabulary"
# "Key 'হয়ে' not present in vocabulary"
# "Key 'খেলায়' not present in vocabulary"
# "Key 'সানিরাতো' not present in vocabulary"
# "Key 'নোংরা' not present in vocabulary"
# "Key 'আপারাধী' not present in vocabulary"
# "Key 'আপারাধী' not present in vocabulary"
# "Key 'আপারাধী' not present in vocabulary"
# "Key 'ওয়েবসাইট' not present in vocabulary"
# "Key 'ওয়েবসাইট' not present in vocabulary"
# "Key 'ওয়েবসাইট' not present in vocabulary"
# "Key 'ওয়েবসাইট' not present in vocabulary"
# "Key 'জিয়া' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'করাকারন' not present in vocabulary"
# "Key 'প্রতিনিয়ত' not present in vocabulary"
# "Key 'মেসিভাইয়ের' not present in vocabulary"
# "Key 'মেসিভাইয়ের' not present in vocabulary"
# "Key 'ভাইয়ের' not present in vocabulary"
# "Key 'বুঝেছি' not present in vocabulary"
# "Key 'হিজরার' not present in vocabulary"
# "Key 'সেখানি' not present in vocabulary"
# "Key 'বিষয়' not present in vocabulary"
# "Key 'বার্সেলোনাই' not present in vocabulary"
# "Key 'ভ্যাটের' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'প্লেয়ারের' not present in vocabulary"
# "Key 'ছাড়' not present in vocabulary"
# "Key 'তাড়াতাড়ি' not present in vocabulary"
# "Key 'অসস্মান' not present in vocabulary"
# "Key 'হয়ে' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'হয়েও' not present in vocabulary"
# "Key 'যেয়' not present in vocabulary"
# "Key 'অমিয়াখুম' not present in vocabulary"
# "Key 'দেয়াই' not present in vocabulary"
# "Key 'কেনএইটা' not present in vocabulary"
# "Key 'নয়' not present in vocabulary"
# "Key 'বিজাতিরা' not present in vocabulary"
# "Key 'আনলাইক' not present in vocabulary"
# "Key 'পাইব' not present in vocabulary"
# "Key 'তাইলে' not present in vocabulary"
# "Key 'হারতেছে' not present in vocabulary"
# "Key 'হারতেছে' not present in vocabulary"
# "Key 'হারতেছে' not present in vocabulary"
# "Key 'হারতেছে' not present in vocabulary"
# "Key 'হারতেছে' not present in vocabulary"
# "Key 'সাড়া' not present in vocabulary"
# "Key 'হয়েছেন' not present in vocabulary"
# "Key 'রুচিই' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'দলঅন্যান্য' not present in vocabulary"
# "Key 'অাপনাকে' not present in vocabulary"
# "Key 'লড়ে' not present in vocabulary"
# "Key 'লড়ে' not present in vocabulary"
# "Key 'নিয়ে' not present in vocabulary"
# "Key 'পরীক্ষকেন্দ্রে' not present in vocabulary"
# "Key 'হারিয়ে' not present in vocabulary"
# "Key 'দিয়ে' not present in vocabulary"
# "Key 'দিয়ে' not present in vocabulary"
# "Key 'দিয়ে' not present in vocabulary"
# "Key 'পাওয়ার' not present in vocabulary"
# "Key 'ভাবেকিন্তু' not present in vocabulary"
# "Key 'সেয়ার' not present in vocabulary"
# "Key 'হইসে' not present in vocabulary"
# "Key 'কর্মসুচীটি' not present in vocabulary"
# "Key 'খোদ' not present in vocabulary"
# "Key 'সন্তাসী' not present in vocabulary"
# "Key 'জতগুলা' not present in vocabulary"
# "Key 'জতগুলা' not present in vocabulary"
# "Key 'নাচলোনা' not present in vocabulary"
# "Key 'ভালকেও' not present in vocabulary"
# "Key 'ইন্টার্ভিউ' not present in vocabulary"
# "Key 'রয়েছে' not present in vocabulary"
# "Key 'জন্ন্য' not present in vocabulary"
# "Key 'ষ্কমা' not present in vocabulary"
# "Key 'বাড়বে' not present in vocabulary"
# "Key 'হয়ে' not present in vocabulary"
# "Key 'হারিয়ে' not present in vocabulary"
# "Key 'পাহাড়' not present in vocabulary"
# "Key 'সাজানোটাও' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'তাসকিনসানি' not present in vocabulary"
# "Key 'উঠেপরে' not present in vocabulary"
# "Key 'ধোকাবাজি' not present in vocabulary"
# "Key 'জাতীয়' not present in vocabulary"
# "Key 'নাছিরসাব্বির' not present in vocabulary"
# "Key 'দিয়ে' not present in vocabulary"
# "Key 'কমেন্ট' not present in vocabulary"
# "Key 'খুজতেছে' not present in vocabulary"
# "Key 'তোমায়' not present in vocabulary"
# "Key 'যায়' not present in vocabulary"
# "Key 'প্লেয়ার' not present in vocabulary"
# "Key 'করাপৃথিবীর' not present in vocabulary"
# "Key 'গোড়ার' not present in vocabulary"
# "Key 'গোড়ার' not present in vocabulary"
# "Key 'চিরজীবন' not present in vocabulary"
# "Key 'ছাড়পোকার' not present in vocabulary"
# "Key 'ছাড়পোকার' not present in vocabulary"
# "Key 'ব্রিশো' not present in vocabulary"
# "Key 'থ্যাঙ্কস' not present in vocabulary"
# "Key 'বলেছিলোএই' not present in vocabulary"
# "Key 'উদ্দিপনা' not present in vocabulary"
# "Key 'হয়ে' not present in vocabulary"
# "Key 'জড়তাও' not present in vocabulary"
# "Key 'অনেকন্ধিরে' not present in vocabulary"
# "Key 'পুরাই' not present in vocabulary"
# "Key 'পুরাই' not present in vocabulary"
# "Key 'জোচ্চোরীর' not present in vocabulary"
# "Key 'ফিরতেছে' not present in vocabulary"
# "Key 'ওয়ানডেতে' not present in vocabulary"
# "Key 'ফিরতেছে' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'ক্যারিয়ার' not present in vocabulary"
# "Key 'মস্কিল' not present in vocabulary"
# "Key 'বুজা' not present in vocabulary"
# "Key 'দিয়া' not present in vocabulary"
# "Key 'দিয়া' not present in vocabulary"
# "Key 'সময়' not present in vocabulary"
# "Key 'প্রয়োজন' not present in vocabulary"
# "Key 'গেছিজানিনা' not present in vocabulary"
# "Key 'গেছিজানিনা' not present in vocabulary"
# "Key 'ডাইরেট' not present in vocabulary"
# "Key 'ডাইরেট' not present in vocabulary"
# "Key 'আছিনিয়াআজব' not present in vocabulary"
# "Key 'এলাকায়' not present in vocabulary"
# "Key 'বাছান' not present in vocabulary"
# "Key 'বাছান' not present in vocabulary"
# "Key 'বাছান' not present in vocabulary"
# "Key 'বানাইয়া' not present in vocabulary"
# "Key 'হয়রানি' not present in vocabulary"
# "Key 'বারতের' not present in vocabulary"
# "Key 'হয়রানি' not present in vocabulary"
# "Key 'ফেবুকে' not present in vocabulary"
# "Key 'জয়' not present in vocabulary"
# "Key 'জয়' not present in vocabulary"
# "Key 'দেয়' not present in vocabulary"
# "Key 'দেয়' not present in vocabulary"
# "Key 'লেখাটা' not present in vocabulary"
# "Key 'নিয়োজিত' not present in vocabulary"
# "Key 'ওটাও' not present in vocabulary"
# "Key 'ষরযন্ত্র' not present in vocabulary"
# "Key 'ওটাও' not present in vocabulary"
# "Key 'কমেন্ট' not present in vocabulary"
# "Key 'দেখিয়ে' not present in vocabulary"
# "Key 'দেখিয়ে' not present in vocabulary"
# "Key 'দেখিয়ে' not present in vocabulary"
# "Key 'লাগব' not present in vocabulary"
# "Key 'লাগব' not present in vocabulary"
# "Key 'হওয়া' not present in vocabulary"
# "Key 'ধিক' not present in vocabulary"
# "Key 'ইন্ডিয়া' not present in vocabulary"
# "Key 'চোষেন' not present in vocabulary"
# "Key 'চোষেন' not present in vocabulary"
# "Key 'জয়' not present in vocabulary"
# "Key 'জয়' not present in vocabulary"
# "Key 'কয়েক' not present in vocabulary"
# "Key 'গর্বিতভালোবাসি' not present in vocabulary"
# "Key 'বাললাগেনা' not present in vocabulary"
# "Key 'বাললাগেনা' not present in vocabulary"
# "Key 'বাললাগেনা' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'যাওয়া' not present in vocabulary"
# "Key 'ভারতিয়' not present in vocabulary"
# "Key 'হয়ে' not present in vocabulary"
# "Key 'পোলাপান' not present in vocabulary"
# "Key 'পোলাপান' not present in vocabulary"
# "Key 'পাওয়া' not present in vocabulary"
# "Key 'গিয়ে' not present in vocabulary"
# "Key 'হয়ে' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'কয়েক' not present in vocabulary"
# "Key 'উচিৎসেটা' not present in vocabulary"
# "Key 'কয়েক' not present in vocabulary"
# "Key 'মূল্যায়ন' not present in vocabulary"
# "Key 'করেছিলকত' not present in vocabulary"
# "Key 'শিক্কা' not present in vocabulary"
# "Key 'বিজয়ের' not present in vocabulary"
# "Key 'ভয়ংকর' not present in vocabulary"
# "Key 'রেসাল্টের' not present in vocabulary"
# "Key 'সময়ের' not present in vocabulary"
# "Key 'যুগান্তরিক' not present in vocabulary"
# "Key 'নিয়া' not present in vocabulary"
# "Key 'ছিলমিথ্যা' not present in vocabulary"
# "Key 'ইন্ডিয়ার' not present in vocabulary"
# "Key 'খেলোয়াড়' not present in vocabulary"
# "Key 'ব্যবসায়' not present in vocabulary"
# "Key 'বায়মেট্রিক' not present in vocabulary"
# "Key 'ভয়' not present in vocabulary"
# "Key 'ভয়' not present in vocabulary"
# "Key 'টাকাগুলোকে' not present in vocabulary"
# "Key 'চুলকানী' not present in vocabulary"
# "Key 'চাইচাইনা' not present in vocabulary"
# "Key 'মাসরাফি' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'হয়েছে' not present in vocabulary"
# "Key 'দেয়' not present in vocabulary"
# "Key 'নয়তো' not present in vocabulary"
# "Key 'হয়নি' not present in vocabulary"
# "Key 'হয়ে' not present in vocabulary"
# "Key 'দায়িত্ত' not present in vocabulary"
# "Key 'দাড়' not present in vocabulary"
# "Key 'করালো' not present in vocabulary"
# "Key 'হয়ে' not present in vocabulary"
# "Key 'হয়ে' not present in vocabulary"
# "Key 'খাইছে' not present in vocabulary"
# "Key 'তালিকায়' not present in vocabulary"
# "Key 'ভয়' not present in vocabulary"
# "Key 'হিন্দুরাএটা' not present in vocabulary"
# "Key 'নয়' not present in vocabulary"
# "Key 'বড়' not present in vocabulary"
# "Key 'শালাকে' not present in vocabulary"
# "Key 'কথায়' not present in vocabulary"
# "Key 'সাপোট' not present in vocabulary"
# "Key 'বাচ্চারাইসলাম' not present in vocabulary"
# "Key 'চায়না' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'ইন্দোনেশিয়া' not present in vocabulary"
# "Key 'ইন্দোনেশিয়া' not present in vocabulary"
# "Key 'আওয়াজ' not present in vocabulary"
# "Key 'শুভেচছা' not present in vocabulary"
# "Key 'খেলোয়ারকে' not present in vocabulary"
# "Key 'শালারা' not present in vocabulary"
# "Key 'হওয়ার' not present in vocabulary"
# "Key 'শেয়ার' not present in vocabulary"
# "Key 'পেয়েও' not present in vocabulary"
# "Key 'হান্নানের' not present in vocabulary"
# "Key 'কৈতাবুড়ি' not present in vocabulary"
# "Key 'কৈতাবুড়ি' not present in vocabulary"
# "Key 'করেআবার' not present in vocabulary"
# "Key 'করেআবার' not present in vocabulary"
# "Key 'করেআবার' not present in vocabulary"
# "Key 'মালাউনের' not present in vocabulary"
# "Key 'মালাউনের' not present in vocabulary"
# "Key 'নয়' not present in vocabulary"
# "Key 'নয়' not present in vocabulary"
# "Key 'তমি' not present in vocabulary"
# "Key 'ধন্যবাদতারা' not present in vocabulary"
# "Key 'প্রতিক্ষায়' not present in vocabulary"
# "Key 'প্রতিক্ষায়' not present in vocabulary"
# "Key 'নাধন্যবাদ' not present in vocabulary"
# "Key 'নায়ক' not present in vocabulary"
# "Key 'আছেযাদের' not present in vocabulary"
# "Key 'আসলী' not present in vocabulary"
# "Key 'ছেড়ে' not present in vocabulary"
# "Key 'আসলী' not present in vocabulary"
# "Key 'স্পেসেফিক' not present in vocabulary"
# "Key 'কর্মস' not present in vocabulary"
# "Key 'জয়বাংলা' not present in vocabulary"
# "Key 'জয়বাংলা' not present in vocabulary"
# "Key 'জয়বাংলা' not present in vocabulary"
# "Key 'জয়বাংলা' not present in vocabulary"
# "Key 'জয়বাংলা' not present in vocabulary"
# "Key 'নেয়া' not present in vocabulary"
# "Key 'খাওয়ার' not present in vocabulary"
# "Key 'খাওয়ার' not present in vocabulary"
# "Key 'স্কয়ার' not present in vocabulary"
# "Key 'হয়নি' not present in vocabulary"
# "Key 'হবেযেকরেই' not present in vocabulary"
# "Key 'তাস্কিন' not present in vocabulary"
# "Key 'দেওয়া' not present in vocabulary"
# "Key 'গরীবেরা' not present in vocabulary"
# "Key 'গরীবেরা' not present in vocabulary"
# "Key 'কথায়' not present in vocabulary"
# "Key 'আইনআমি' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'নিয়ে' not present in vocabulary"
# "Key 'ভয়ানক' not present in vocabulary"
# "Key 'ভয়ানক' not present in vocabulary"
# "Key 'স্বৈরাচারীতা' not present in vocabulary"
# "Key 'সবচেয়ে' not present in vocabulary"
# "Key 'আওয়াজ' not present in vocabulary"
# "Key 'আওয়াজ' not present in vocabulary"
# "Key 'শালারা' not present in vocabulary"
# "Key 'কথাতবে' not present in vocabulary"
# "Key 'নাভ্যাট' not present in vocabulary"
# "Key 'দেওয়ার' not present in vocabulary"
# "Key 'রয়েছে' not present in vocabulary"
# "Key 'ততধারা' not present in vocabulary"
# "Key 'অপারাধ' not present in vocabulary"
# "Key 'আাইনের' not present in vocabulary"
# "Key 'জাপানইন্দোনেশিয়ায়' not present in vocabulary"
# "Key 'জাপানইন্দোনেশিয়ায়' not present in vocabulary"
# "Key 'লাগলোএটা' not present in vocabulary"
# "Key 'লাগলোএটা' not present in vocabulary"
# "Key 'জাপানইন্দোনেশিয়ায়' not present in vocabulary"
# "Key 'সমজতন্ত্রের' not present in vocabulary"
# "Key 'হইতাম' not present in vocabulary"
# "Key 'মূলুক' not present in vocabulary"
# "Key 'বলেছেদেখি' not present in vocabulary"
# "Key 'সময়' not present in vocabulary"
# "Key 'সময়' not present in vocabulary"
# "Key 'দেয়াল' not present in vocabulary"
# "Key 'রতনে' not present in vocabulary"
# "Key 'শালাদের' not present in vocabulary"
# "Key 'পড়ে' not present in vocabulary"
# "Key 'পড়ে' not present in vocabulary"
# "Key 'ঢাকায়' not present in vocabulary"
# "Key 'ভাইয়া' not present in vocabulary"
# "Key 'ভাইয়া' not present in vocabulary"
# "Key 'ছিনিমিনি' not present in vocabulary"
# "Key 'খেলোয়ার' not present in vocabulary"
# "Key 'ছিনিমিনি' not present in vocabulary"
# "Key 'ছিনিমিনি' not present in vocabulary"
# "Key 'খেলোয়ার' not present in vocabulary"
# "Key 'নিশ্চয়ই' not present in vocabulary"
# "Key 'নিশ্চয়ই' not present in vocabulary"
# "Key 'সময়' not present in vocabulary"
# "Key 'ঐকব্ধধ্য' not present in vocabulary"
# "Key 'কার্টুনটা' not present in vocabulary"
# "Key 'দিয়েছিলো' not present in vocabulary"
# "Key 'রেজাল্টে' not present in vocabulary"
# "Key 'বিতর্কটা' not present in vocabulary"
# "Key 'নিয়ে' not present in vocabulary"
# "Key 'বিতর্কটা' not present in vocabulary"
# "Key 'প্রিয়' not present in vocabulary"
# "Key 'ভারতীয়' not present in vocabulary"
# "Key 'দিবএত' not present in vocabulary"
# "Key 'নাযাইব' not present in vocabulary"
# "Key 'দেয়' not present in vocabulary"
# "Key 'খায়' not present in vocabulary"
# "Key 'খায়' not present in vocabulary"
# "Key 'কিনলো' not present in vocabulary"
# "Key 'কিনলো' not present in vocabulary"
# "Key 'কিনলো' not present in vocabulary"
# "Key 'কামড়' not present in vocabulary"
# "Key 'পুরাই' not present in vocabulary"
# "Key 'কামড়' not present in vocabulary"
# "Key 'নয়জীবন' not present in vocabulary"
# "Key 'দিতেছি' not present in vocabulary"
# "Key 'বয়স' not present in vocabulary"
# "Key 'বয়স' not present in vocabulary"
# "Key 'বয়স' not present in vocabulary"
# "Key 'ডাকাতশিক্ষিত' not present in vocabulary"
# "Key 'সুখবরটা' not present in vocabulary"
# "Key 'আহ্অনেকদিন' not present in vocabulary"
# "Key 'মোদ্দা' not present in vocabulary"
# "Key 'প্রথমআলো' not present in vocabulary"
# "Key 'প্রথমআলো' not present in vocabulary"
# "Key 'পৃখথিবী' not present in vocabulary"
# "Key 'জয়' not present in vocabulary"
# "Key 'জয়' not present in vocabulary"
# "Key 'মাবিয়ার' not present in vocabulary"
# "Key 'বেশতো' not present in vocabulary"
# "Key 'সুন্দরহাসিময়' not present in vocabulary"
# "Key 'মায়েরা' not present in vocabulary"
# "Key 'মায়েরা' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'চালিয়ে' not present in vocabulary"
# "Key 'নাহাজার' not present in vocabulary"
# "Key 'নায়কদেরবেঁচে' not present in vocabulary"
# "Key 'চায়' not present in vocabulary"
# "Key 'চায়' not present in vocabulary"
# "Key 'বাংলায়' not present in vocabulary"
# "Key 'মাসাল্লাহ্' not present in vocabulary"
# "Key 'দেখাছে' not present in vocabulary"
# "Key 'মাসাল্লাহ্' not present in vocabulary"
# "Key 'মানুষযতই' not present in vocabulary"
# "Key 'বিশ্ববিদ্যালয়ের' not present in vocabulary"
# "Key 'বায়োমেট্রিক' not present in vocabulary"
# "Key 'বায়োমেট্রিক' not present in vocabulary"
# "Key 'শোয়েব' not present in vocabulary"
# "Key 'মদদের' not present in vocabulary"
# "Key 'করুনআমিন' not present in vocabulary"
# "Key 'দোয়া' not present in vocabulary"
# "Key 'হারবোও' not present in vocabulary"
# "Key 'শিখিনি' not present in vocabulary"
# "Key 'খেলোয়ার' not present in vocabulary"
# "Key 'নিয়ে' not present in vocabulary"
# "Key 'আলোকে' not present in vocabulary"
# "Key 'হারিয়ে' not present in vocabulary"
# "Key 'ময়লা' not present in vocabulary"
# "Key 'ময়লা' not present in vocabulary"
# "Key 'স্বপ্নভাঙ্গারবিচারহবেকিএইদেশে' not present in vocabulary"
# "Key 'স্বপ্নভাঙ্গারবিচারহবেকিএইদেশে' not present in vocabulary"
# "Key 'স্বপ্নভাঙ্গারবিচারহবেকিএইদেশে' not present in vocabulary"
# "Key 'স্বপ্নভাঙ্গারবিচারহবেকিএইদেশে' not present in vocabulary"
# "Key 'স্বপ্নভাঙ্গারবিচারহবেকিএইদেশে' not present in vocabulary"
# "Key 'হয়েছেনআজব' not present in vocabulary"
# "Key 'মিডিয়া' not present in vocabulary"
# "Key 'চ্যানেলনিউজ' not present in vocabulary"
# "Key 'কোথায়' not present in vocabulary"
# "Key 'নিয়া' not present in vocabulary"
# "Key 'হরিয়ে' not present in vocabulary"
# "Key 'হয়না' not present in vocabulary"
# "Key 'হয়না' not present in vocabulary"
# "Key 'গালির' not present in vocabulary"
# "Key 'হালারে' not present in vocabulary"
# "Key 'জম্ম' not present in vocabulary"
# "Key 'উবায়দুল' not present in vocabulary"
# "Key 'উবায়দুল' not present in vocabulary"
# "Key 'হইয়া' not present in vocabulary"
# "Key 'হইয়া' not present in vocabulary"
# "Key 'শালার' not present in vocabulary"
# "Key 'শালার' not present in vocabulary"
# "Key 'কোনো' not present in vocabulary"
# "Key 'হিজড়া' not present in vocabulary"
# "Key 'ভাইয়া' not present in vocabulary"
# "Key 'ভাইয়া' not present in vocabulary"
# "Key 'বাহ্' not present in vocabulary"
# "Key 'পায়নি' not present in vocabulary"
# "Key 'স্যালুটজানাই' not present in vocabulary"
# "Key 'স্যালুটজানাই' not present in vocabulary"
# "Key 'ভাইবোনদেরকে' not present in vocabulary"
# "Key 'স্যালুটজানাই' not present in vocabulary"
# "Key 'বেকুব' not present in vocabulary"
# "Key 'খাকলাম' not present in vocabulary"
# "Key 'বিষয়' not present in vocabulary"
# "Key 'ভক্তিবিষয়ক' not present in vocabulary"
# "Key 'ভক্তিবিষয়ক' not present in vocabulary"
# "Key 'পাঠ্যবইএ' not present in vocabulary"
# "Key 'পাঠ্যবইএ' not present in vocabulary"
# "Key 'ভাইয়া' not present in vocabulary"
# "Key 'ভাইয়া' not present in vocabulary"
# "Key 'ঘটনায়' not present in vocabulary"
# "Key 'হয়রানি' not present in vocabulary"
# "Key 'আইনশৃঙ্খলাবাহিনী' not present in vocabulary"
# "Key 'পেয়ে' not present in vocabulary"
# "Key 'সবগুলা' not present in vocabulary"
# "Key 'সবগুলা' not present in vocabulary"
# "Key 'জামায়াতশিবির' not present in vocabulary"
# "Key 'ষড়যন্ত্রকারিরা' not present in vocabulary"
# "Key 'লোমগুলা' not present in vocabulary"
# "Key 'ঝরলো' not present in vocabulary"
# "Key 'সবচেয়ে' not present in vocabulary"
# "Key 'সবচেয়ে' not present in vocabulary"
# "Key 'সবচেয়ে' not present in vocabulary"
# "Key 'পুরাই' not present in vocabulary"
# "Key 'ছোটবেলায়' not present in vocabulary"
# "Key 'ছোটবেলায়' not present in vocabulary"
# "Key 'পড়েছে' not present in vocabulary"
# "Key 'বাড়ী' not present in vocabulary"
# "Key 'থাইকা' not present in vocabulary"
# "Key 'কিছো' not present in vocabulary"
# "Key 'মোটি' not present in vocabulary"
# "Key 'মোটি' not present in vocabulary"
# "Key 'একনো' not present in vocabulary"
# "Key 'চোরসন্ত্রাসসামরাজ্জ্যবাদ' not present in vocabulary"
# "Key 'চোরসন্ত্রাসসামরাজ্জ্যবাদ' not present in vocabulary"
# "Key 'চোরসন্ত্রাসসামরাজ্জ্যবাদ' not present in vocabulary"
# "Key 'চোরসন্ত্রাসসামরাজ্জ্যবাদ' not present in vocabulary"
# "Key 'ক্রন্দনতাই' not present in vocabulary"
# "Key 'পুড়ে' not present in vocabulary"
# "Key 'পুড়ে' not present in vocabulary"
# "Key 'পুড়ে' not present in vocabulary"
# "Key 'পুড়ে' not present in vocabulary"
# "Key 'হৃত্বিক' not present in vocabulary"
# "Key 'বসিয়ে' not present in vocabulary"
# "Key 'রইলাম' not present in vocabulary"
# "Key 'ইতালিজয়' not present in vocabulary"
# "Key 'ইতালিজয়' not present in vocabulary"
# "Key 'দিয়েই' not present in vocabulary"
# "Key 'পক্ষেতবে' not present in vocabulary"
# "Key 'জিততেআফগানরা' not present in vocabulary"
# "Key 'যায়' not present in vocabulary"
# "Key 'নার্বাচিত' not present in vocabulary"
# "Key 'ক্ষমতায়' not present in vocabulary"
# "Key 'বাংলাটা' not present in vocabulary"
# "Key 'বাংলাটা' not present in vocabulary"
# "Key 'হিজ্রারাও' not present in vocabulary"
# "Key 'সজনরা' not present in vocabulary"
# "Key 'মানায়' not present in vocabulary"
# "Key 'মানায়' not present in vocabulary"
# "Key 'মানায়' not present in vocabulary"
# "Key 'টেক্সে' not present in vocabulary"
# "Key 'স্বাধ' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'কুওার' not present in vocabulary"
# "Key 'দেয়' not present in vocabulary"
# "Key 'পরুক' not present in vocabulary"
# "Key 'ছেলেমেয়ে' not present in vocabulary"
# "Key 'অভিনন্দনও' not present in vocabulary"
# "Key 'অনস্থল' not present in vocabulary"
# "Key 'নিয়েগেছো' not present in vocabulary"
# "Key 'ফিজবিশ্বের' not present in vocabulary"
# "Key 'পলিব্যাগে' not present in vocabulary"
# "Key 'পলিব্যাগে' not present in vocabulary"
# "Key 'রদ্রে' not present in vocabulary"
# "Key 'অসহায়' not present in vocabulary"
# "Key '⏰' not present in vocabulary"
# "Key 'নষ্টদের' not present in vocabulary"
# "Key 'ভয়াবহ' not present in vocabulary"
# "Key 'ভয়াবহ' not present in vocabulary"
# "Key 'ভয়াবহ' not present in vocabulary"
# "Key 'ভয়াবহ' not present in vocabulary"
# "Key 'ভয়াবহ' not present in vocabulary"
# "Key 'গোয়াল' not present in vocabulary"
# "Key 'গোয়াল' not present in vocabulary"
# "Key 'চেয়ে' not present in vocabulary"
# "Key 'আজাইরা' not present in vocabulary"
# "Key 'আজাইরা' not present in vocabulary"
# "Key 'আজাইরা' not present in vocabulary"
# "Key 'আজাইরা' not present in vocabulary"
# "Key 'আজাইরা' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'নুনুর' not present in vocabulary"
# "Key 'রেন্ডিয়া' not present in vocabulary"
# "Key 'রেন্ডিয়া' not present in vocabulary"
# "Key 'ইনশাল্লাহ্' not present in vocabulary"
# "Key 'চালাইবা' not present in vocabulary"
# "Key 'মেয়েপক্ষ' not present in vocabulary"
# "Key 'পায়ের' not present in vocabulary"
# "Key 'পায়ের' not present in vocabulary"
# "Key 'পায়ের' not present in vocabulary"
# "Key 'দুর্নীতিবাজদের' not present in vocabulary"
# "Key 'দুর্নীতিবাজদের' not present in vocabulary"
# "Key 'জড়িত' not present in vocabulary"
# "Key 'চ্যানেলগুলোর' not present in vocabulary"
# "Key 'জানোয়ার' not present in vocabulary"
# "Key 'জানোয়ার' not present in vocabulary"
# "Key 'অপরাধীরাও' not present in vocabulary"
# "Key 'পালটি' not present in vocabulary"
# "Key 'পালটি' not present in vocabulary"
# "Key 'নাইতারা' not present in vocabulary"
# "Key 'ফাজলামী' not present in vocabulary"
# "Key 'ফাজলামী' not present in vocabulary"
# "Key 'ফাজলামী' not present in vocabulary"
# "Key 'ফাজলামী' not present in vocabulary"
# "Key 'বার্সাকে' not present in vocabulary"
# "Key 'এগিয়ে' not present in vocabulary"
# "Key 'হাইকোটে' not present in vocabulary"
# "Key 'করেছেতাকে' not present in vocabulary"
# ...
# "Key 'দেওয়া' not present in vocabulary"
# "Key 'খেলোয়ারের' not present in vocabulary"
# "Key 'হলকুয়েট' not present in vocabulary"
# "Key 'পেজতাই' not present in vocabulary"
# "Key 'তৈমর' not present in vocabulary"
# "Key 'আললা' not present in vocabulary"
# "Key 'ফিলকরবে' not present in vocabulary"
# "Key 'অদের' not present in vocabulary"
# "Key 'অবস্থায়' not present in vocabulary"
# "Key 'পায়ের' not present in vocabulary"
# "Key 'পায়ের' not present in vocabulary"
# "Key 'পায়ের' not present in vocabulary"
# "Key 'বেহস্ত' not present in vocabulary"
# "Key 'নায়ক' not present in vocabulary"
# "Key 'নায়ক' not present in vocabulary"
# "Key 'চলছিসআললাহর' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'কিনলাম' not present in vocabulary"
# "Key 'হয়েছেএবার' not present in vocabulary"
# "Key 'চালিয়ে' not present in vocabulary"
# "Key 'মারব' not present in vocabulary"
# "Key 'শ্মশাণে' not present in vocabulary"
# "Key 'শ্মশাণে' not present in vocabulary"
# "Key 'দিয়ে' not present in vocabulary"
# "Key 'সবচেয়ে' not present in vocabulary"
# "Key 'জিয়া' not present in vocabulary"
# "Key 'জিয়া' not present in vocabulary"
# "Key 'মন্এী' not present in vocabulary"
# "Key 'জড়িত' not present in vocabulary"
# "Key 'হইয়া' not present in vocabulary"
# "Key 'টাকায়আমি' not present in vocabulary"
# "Key 'পণ্যতবে' not present in vocabulary"
# "Key 'আছেভ্যাট' not present in vocabulary"
# "Key 'হয়ে' not present in vocabulary"
# "Key 'প্রতিক্রিয়া' not present in vocabulary"
# "Key 'নয়' not present in vocabulary"
# "Key 'বিলাই' not present in vocabulary"
# "Key 'দিয়েছিল' not present in vocabulary"
# "Key 'চায়' not present in vocabulary"
# "Key 'প্রিয়' not present in vocabulary"
# "Key 'নারীদেরকেও' not present in vocabulary"
# "Key 'নারীদেরকেও' not present in vocabulary"
# "Key 'খাইলিরুপালি' not present in vocabulary"
# "Key 'এক্সিডেন্টে' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'ইন্দোনেশিয়ার' not present in vocabulary"
# "Key 'বিষয়ে' not present in vocabulary"
# "Key 'হয়ে' not present in vocabulary"
# "Key 'গিয়েছিলেন' not present in vocabulary"
# "Key 'চুলকায়' not present in vocabulary"
# "Key 'দেয়' not present in vocabulary"
# "Key 'অল্পকথামালার' not present in vocabulary"
# "Key 'ছোঁয়ায়' not present in vocabulary"
# "Key 'বাজিয়ে' not present in vocabulary"
# "Key 'ভাড়া' not present in vocabulary"
# "Key 'ভাড়া' not present in vocabulary"
# "Key 'উচিততাহলে' not present in vocabulary"
# "Key 'মেলাসাথে' not present in vocabulary"
# "Key 'দিয়ে' not present in vocabulary"
# "Key 'ভাঙলেন' not present in vocabulary"
# "Key 'টায়' not present in vocabulary"
# "Key 'টায়' not present in vocabulary"
# "Key 'গাতিও' not present in vocabulary"
# "Key 'আশীর্বাদক' not present in vocabulary"
# "Key 'করছথ্যাংক' not present in vocabulary"
# "Key 'সময়টা' not present in vocabulary"
# "Key 'করছথ্যাংক' not present in vocabulary"
# "Key 'দেয়' not present in vocabulary"
# "Key 'হয়েছে' not present in vocabulary"
# "Key 'তরুনের' not present in vocabulary"
# "Key 'জানিনাতবে' not present in vocabulary"
# "Key 'বিশ্বজুড়ে' not present in vocabulary"
# "Key 'নিয়ে' not present in vocabulary"
# "Key 'পেয়েছি' not present in vocabulary"
# "Key 'পেয়েছি' not present in vocabulary"
# "Key 'নিচ্ছিলাম' not present in vocabulary"
# "Key 'ণিজেকে' not present in vocabulary"
# "Key 'লাফান' not present in vocabulary"
# "Key 'দিয়া' not present in vocabulary"
# "Key 'বড়' not present in vocabulary"
# "Key 'পরিচয়' not present in vocabulary"
# "Key 'নয' not present in vocabulary"
# "Key 'গতিমানব' not present in vocabulary"
# "Key 'সাবাশ' not present in vocabulary"
# "Key 'সাবাশ' not present in vocabulary"
# "Key 'সাবাশ' not present in vocabulary"
# "Key 'সাবাশ' not present in vocabulary"
# "Key 'সাবাশ' not present in vocabulary"
# "Key 'জয়' not present in vocabulary"
# "Key 'পড়ুক' not present in vocabulary"
# "Key 'বিডিতে' not present in vocabulary"
# "Key 'শাড়ি' not present in vocabulary"
# "Key 'ভিয়ে' not present in vocabulary"
# "Key 'সেন্ডিকেট' not present in vocabulary"
# "Key 'সেন্ডিকেট' not present in vocabulary"
# "Key 'পড়তে' not present in vocabulary"
# "Key 'কয়েকবার' not present in vocabulary"
# "Key 'পড়তে' not present in vocabulary"
# "Key 'কোঠায়' not present in vocabulary"
# "Key 'কোঠায়' not present in vocabulary"
# "Key 'কোঠায়' not present in vocabulary"
# "Key 'জয়টা' not present in vocabulary"
# "Key 'জন্নেই' not present in vocabulary"
# "Key 'নায়ক' not present in vocabulary"
# "Key 'সথ্যি' not present in vocabulary"
# "Key 'সময়' not present in vocabulary"
# "Key 'অপসংস্কৃতি' not present in vocabulary"
# "Key 'অপসংস্কৃতি' not present in vocabulary"
# "Key 'অপসংস্কৃতি' not present in vocabulary"
# "Key 'অপসংস্কৃতি' not present in vocabulary"
# "Key 'অপসংস্কৃতি' not present in vocabulary"
# "Key 'অার্ধেক' not present in vocabulary"
# "Key 'অার্ধেক' not present in vocabulary"
# "Key 'খবিশের' not present in vocabulary"
# "Key 'দেওয়া' not present in vocabulary"
# "Key 'দেওয়া' not present in vocabulary"
# "Key 'অমানুষীকতা' not present in vocabulary"
# "Key 'কয়েক' not present in vocabulary"
# "Key 'ধুয়ে' not present in vocabulary"
# "Key 'অপসংস্কৃতি' not present in vocabulary"
# "Key 'মায়ের' not present in vocabulary"
# "Key 'পাগলছাগলের' not present in vocabulary"
# "Key 'যতসব' not present in vocabulary"
# "Key 'পাগলছাগলের' not present in vocabulary"
# "Key 'খাজানা' not present in vocabulary"
# "Key 'পতিদিন' not present in vocabulary"
# "Key 'রিয়ালমাদ্রিদফ্যান' not present in vocabulary"
# "Key 'রাবিশ' not present in vocabulary"
# "Key 'রাবিশ' not present in vocabulary"
# "Key 'রাবিশ' not present in vocabulary"
# "Key 'রাবিশ' not present in vocabulary"
# "Key 'রাবিশ' not present in vocabulary"
# "Key 'খাইতে' not present in vocabulary"
# "Key 'হইনিআরও' not present in vocabulary"
# "Key 'এগিয়ে' not present in vocabulary"
# "Key 'হইনিআরও' not present in vocabulary"
# "Key 'ঠিকি' not present in vocabulary"
# "Key 'মানায়' not present in vocabulary"
# "Key 'মানায়' not present in vocabulary"
# "Key 'পায়নি' not present in vocabulary"
# "Key 'পেরিয়ে' not present in vocabulary"
# "Key 'দিকেএভাবে' not present in vocabulary"
# "Key 'হবেইইনশাআল্লাহ' not present in vocabulary"
# "Key 'জয়' not present in vocabulary"
# "Key 'খারাপই' not present in vocabulary"
# "Key 'খারাপই' not present in vocabulary"
# "Key 'চেয়ে' not present in vocabulary"
# "Key 'দিয়ে' not present in vocabulary"
# "Key 'ইউরোপীয়' not present in vocabulary"
# "Key 'ভয়ে' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'নয়' not present in vocabulary"
# "Key 'হয়েছে' not present in vocabulary"
# "Key 'হয়েছে' not present in vocabulary"
# "Key 'বড়' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'টয়লেট' not present in vocabulary"
# "Key 'টয়লেট' not present in vocabulary"
# "Key 'ছেলেমেয়েদের' not present in vocabulary"
# "Key 'ছেলেমেয়েদের' not present in vocabulary"
# "Key 'যাওয়া' not present in vocabulary"
# "Key 'খাওয়া' not present in vocabulary"
# "Key 'নয়জয়ের' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'ছাড়াই' not present in vocabulary"
# "Key 'হিজড়া' not present in vocabulary"
# "Key 'করেআজব' not present in vocabulary"
# "Key 'করেআজব' not present in vocabulary"
# "Key 'করলেনতবে' not present in vocabulary"
# "Key 'মাননীয়' not present in vocabulary"
# "Key 'কিছুইতো' not present in vocabulary"
# "Key 'প্রচেস্টার' not present in vocabulary"
# "Key 'ভাইয়ের' not present in vocabulary"
# "Key 'দলীয়সম্মিলিত' not present in vocabulary"
# "Key 'প্রচেস্টার' not present in vocabulary"
# "Key 'চায়' not present in vocabulary"
# "Key 'শেয়াল' not present in vocabulary"
# "Key 'শেয়াল' not present in vocabulary"
# "Key 'প্রতিবেদনটা' not present in vocabulary"
# "Key 'এছাড়াও' not present in vocabulary"
# "Key 'দয়াকরে' not present in vocabulary"
# "Key 'এছাড়াও' not present in vocabulary"
# "Key 'লিখাটা' not present in vocabulary"
# "Key 'লিখাটা' not present in vocabulary"
# "Key 'লিখাটা' not present in vocabulary"
# "Key 'লিখাটা' not present in vocabulary"
# "Key 'দুঃক্ষিত' not present in vocabulary"
# "Key 'এ্যংগেল' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'মাইয়ার' not present in vocabulary"
# "Key 'পড়েন' not present in vocabulary"
# "Key 'কমেন্ট' not present in vocabulary"
# "Key 'নাহয়' not present in vocabulary"
# "Key 'রাগঅভিমানই' not present in vocabulary"
# "Key 'কেমেরা' not present in vocabulary"
# "Key 'জানোয়ার' not present in vocabulary"
# "Key 'জানোয়ার' not present in vocabulary"
# "Key 'মালদের' not present in vocabulary"
# "Key 'এজন্যইত' not present in vocabulary"
# "Key 'ধ্বংসই' not present in vocabulary"
# "Key 'ছিঃ' not present in vocabulary"
# "Key 'খাওয়া' not present in vocabulary"
# "Key 'পড়শী' not present in vocabulary"
# "Key 'পড়শী' not present in vocabulary"
# "Key 'পড়শী' not present in vocabulary"
# "Key 'হয়ে' not present in vocabulary"
# "Key 'নাএই' not present in vocabulary"
# "Key 'দুএকজন' not present in vocabulary"
# "Key 'খৈমুরকিছু' not present in vocabulary"
# "Key 'চালচতুরী' not present in vocabulary"
# "Key 'হায়রে' not present in vocabulary"
# "Key 'রাস্তায়' not present in vocabulary"
# "Key 'গাড়ি' not present in vocabulary"
# "Key 'খরছ' not present in vocabulary"
# "Key 'ছাড়া' not present in vocabulary"
# "Key 'কয়জনইবা' not present in vocabulary"
# "Key 'কর্মসুচীটি' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'ভাসিয়ে' not present in vocabulary"
# "Key 'চোরটা' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'অর্থণীতিতে' not present in vocabulary"
# "Key 'অর্থণীতিতে' not present in vocabulary"
# "Key 'বাটপার' not present in vocabulary"
# "Key 'বাটপার' not present in vocabulary"
# "Key 'বাটপার' not present in vocabulary"
# "Key 'নয়' not present in vocabulary"
# "Key 'হয়ছে' not present in vocabulary"
# "Key 'জর্দার' not present in vocabulary"
# "Key 'হাকিমপুরী' not present in vocabulary"
# "Key 'বড়' not present in vocabulary"
# "Key 'হাকিমপুরী' not present in vocabulary"
# "Key 'হাহাহা' not present in vocabulary"
# "Key 'হাহাহা' not present in vocabulary"
# "Key 'হাহাহা' not present in vocabulary"
# "Key 'হাহাহা' not present in vocabulary"
# "Key 'প্রশসনীয়' not present in vocabulary"
# "Key 'নিয়ে' not present in vocabulary"
# "Key 'নাবোধক' not present in vocabulary"
# "Key 'সময়' not present in vocabulary"
# "Key 'সময়' not present in vocabulary"
# "Key 'দেয়া' not present in vocabulary"
# "Key 'আন্ডা' not present in vocabulary"
# "Key 'আন্ডা' not present in vocabulary"
# "Key 'দেখিয়ে' not present in vocabulary"
# "Key 'ছাড়া' not present in vocabulary"
# "Key 'ছাড়া' not present in vocabulary"
# "Key 'হয়ে' not present in vocabulary"
# "Key 'আলেয়ার' not present in vocabulary"
# "Key 'দিলেওতো' not present in vocabulary"
# "Key 'দেশীয়' not present in vocabulary"
# "Key 'লিখছস' not present in vocabulary"
# "Key 'লিখছস' not present in vocabulary"
# "Key 'স্বার্থই' not present in vocabulary"
# "Key 'দিয়েছে' not present in vocabulary"
# "Key 'ছড়িয়ে' not present in vocabulary"
# "Key 'বেরিয়ে' not present in vocabulary"
# "Key 'বেরিয়ে' not present in vocabulary"
# "Key 'অবক্ষয়' not present in vocabulary"
# "Key 'অবক্ষয়' not present in vocabulary"
# "Key 'পাবেননা' not present in vocabulary"
# "Key 'নয়' not present in vocabulary"
# "Key 'নয়' not present in vocabulary"
# "Key 'মেয়ের' not present in vocabulary"
# "Key 'মেয়ের' not present in vocabulary"
# "Key 'শুয়ে' not present in vocabulary"
# "Key 'বায়েজীদ' not present in vocabulary"
# "Key 'ছাএলিগ' not present in vocabulary"
# "Key 'শাহারিয়র' not present in vocabulary"
# "Key 'ইন্ডিয়া' not present in vocabulary"
# "Key 'ছাড়া' not present in vocabulary"
# "Key 'ছাড়া' not present in vocabulary"
# "Key 'ষড়যন্ত্র' not present in vocabulary"
# "Key 'আকর্ষণীয়' not present in vocabulary"
# "Key 'তোমায়' not present in vocabulary"
# "Key 'তোমায়' not present in vocabulary"
# "Key 'পাগলামো' not present in vocabulary"
# "Key 'কারতার' not present in vocabulary"
# "Key 'কারতার' not present in vocabulary"
# "Key 'পাগলামো' not present in vocabulary"
# "Key 'রয়েছে' not present in vocabulary"
# "Key 'যায়' not present in vocabulary"
# "Key 'লিঙ্গই' not present in vocabulary"
# "Key 'লিঙ্গই' not present in vocabulary"
# "Key 'অফিশিয়াল' not present in vocabulary"
# "Key 'উথান' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'ছদ্দবেশে' not present in vocabulary"
# "Key 'ধন্যবাদআগে' not present in vocabulary"
# "Key 'পোষ্ট' not present in vocabulary"
# "Key 'ভূয়া' not present in vocabulary"
# "Key 'কোথায়' not present in vocabulary"
# "Key 'হয়ে' not present in vocabulary"
# "Key 'দিয়া' not present in vocabulary"
# "Key 'অামি' not present in vocabulary"
# "Key 'অামি' not present in vocabulary"
# "Key 'দেওয়ার' not present in vocabulary"
# "Key 'দেখিয়ে' not present in vocabulary"
# "Key 'পড়বে' not present in vocabulary"
# "Key 'পড়বে' not present in vocabulary"
# "Key 'খালেদার' not present in vocabulary"
# "Key 'খাহ্' not present in vocabulary"
# "Key 'খাহ্' not present in vocabulary"
# "Key 'যেস্থানে' not present in vocabulary"
# "Key 'পাপত্' not present in vocabulary"
# "Key 'এন্ডারসনম্যাক্সওয়েলডুমিনি' not present in vocabulary"
# "Key 'এখনকেন' not present in vocabulary"
# "Key 'খেলায়' not present in vocabulary"
# "Key 'খেলায়' not present in vocabulary"
# "Key 'ঘোড়ার' not present in vocabulary"
# "Key 'ঘোড়ার' not present in vocabulary"
# "Key 'ন্যায়' not present in vocabulary"
# "Key 'হুদাই' not present in vocabulary"
# "Key 'বিষয়' not present in vocabulary"
# "Key 'বস্র' not present in vocabulary"
# "Key 'হালায়' not present in vocabulary"
# "Key 'নিয়া' not present in vocabulary"
# "Key 'নিয়া' not present in vocabulary"
# "Key 'করেনিআইসিসির' not present in vocabulary"
# "Key 'ধোকাবাজ' not present in vocabulary"
# "Key 'কলংক' not present in vocabulary"
# "Key 'ধুয়ে' not present in vocabulary"
# "Key 'উন্নায়নে' not present in vocabulary"
# "Key 'দেওয়ার' not present in vocabulary"
# "Key 'হয়' not present in vocabulary"
# "Key 'গর্বধারিনী' not present in vocabulary"
# "Key 'তুলনাই' not present in vocabulary"
# "Key 'তুলনাই' not present in vocabulary"
# "Key 'প্রত্যয়ের' not present in vocabulary"
# "Key 'প্রত্যয়ের' not present in vocabulary"
# "Key 'মন্ত্রনালয়ে' not present in vocabulary"
# "Key 'ভালবাসাটা' not present in vocabulary"
# "Key 'সবসময়ই' not present in vocabulary"
# "Key 'পাওয়ার' not present in vocabulary"
# "Key 'পাওয়ার' not present in vocabulary"
# "Key 'পাওয়ার' not present in vocabulary"
# "Key 'পাওয়ার' not present in vocabulary"
# "Key 'হবেনানিজের' not present in vocabulary"
# "Key 'জানিয়ে' not present in vocabulary"
# "Key 'বাড়তি' not present in vocabulary"
# "Key 'দিয়ে' not present in vocabulary"
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-37909173a558> in <cell line: 9>()
#       7 # Create a new DataFrame with original and augmented sentences
#       8 new_data = {'original_sentence': flattened_sentences, 'sentiment': df_sampled['sentiment'].repeat(5).tolist()}
# ----> 9 new_df = pd.DataFrame(new_data)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     662         elif isinstance(data, dict):
#     663             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665         elif isinstance(data, ma.MaskedArray):
#     666             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     491             arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
#     492
# --> 493     return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#     494
#     495
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     116         # figure out the index, if necessary
#     117         if index is None:
# --> 118             index = _extract_index(arrays)
#     119         else:
#     120             index = ensure_index(index)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in _extract_index(data)
#     664             lengths = list(set(raw_lengths))
#     665             if len(lengths) > 1:
# --> 666                 raise ValueError("All arrays must be of the same length")
#     667
#     668             if have_dicts:
#
# ValueError: All arrays must be of the same length
